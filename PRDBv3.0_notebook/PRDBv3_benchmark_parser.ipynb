# %% [markdown]
# # Tutorial PRDBv3.0 dataset

# %% [markdown]
# PYTHON LIBRARIES USED

# %%
import os
import sys
import numpy as np
import pandas as pd
import json
import lxml
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read json file

# %%
# Read the JSON file into a pandas DataFrame
prdbv3_read_json = pd.read_json('/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/PRDBv3_pdbList_chains.json')

# %%
prdbv3_read_json
# Out:
#     C_PDB C_chain_PR Structural_class Flexible_class Docking_case  \
# 0    1ASY        A:R                A              R           UU
# 1    1B23        P:R                A              F           UU
# 2    1C0A        A:B                A              S           UU
# 3    1QTQ        A:B                A              S           UU
# 4    2BTE        A:B                A              R           UU
# ..    ...        ...              ...            ...          ...
# 192  2PJP        A:B                C           None           BU
# 193  3BT7        A:C                C           None           BU
# 194  6HTU     ABC:DF                C           None           BU
# 195  1LNG        A:B                D           None           BU
# 196  2I82        A:E                D           None           BU
#
#     Binding_affinity C_pro_chain C_pro_seq_length C_RNA_chain  \
# 0                yes           A              490           R
# 1                 no           P              405           R
# 2                 no           A              585           B
# 3                yes           A              553           B
# 4                 no           A              878           B
# ..               ...         ...              ...         ...
# 192              yes           A              121           B
# 193              yes           A              369           C
# 194              yes         ABC      182+182+182          DF
# 195               no           A               87           B
# 196               no           A              217           E
#
#     C_RNA_seq_length U_pro_PDB U_pro_chain U_pro_seq_length U_RNA_PDB  \
# 0                 75      1EOV           A              487      2TRA
# 1                 74      1TUI           A              405     1U0B*
# 2                 77      1EQR           A              590     1EFW*
# 3                 75      1NYL           A              539     3KNH*
# 4                 83      1OBC           A              878     2NQP*
# ..               ...       ...         ...              ...       ...
# 192               23      None        None             None      1MFK
# 193               19      None        None             None      1EVV
# 194            19+19      None        None             None      6HU6
# 195               97      None        None             None      1Z43
# 196               21      None        None             None      3L0U
#
#     U_RNA_chain U_RNA_seq_length
# 0             A               75
# 1             A               74
# 2             C               73
# 3             Y               75
# 4             F               87
# ..          ...              ...
# 192           A               23
# 193           A               76
# 194          AE            19+19
# 195           A              101
# 196   A (26-43)               76
#
# [197 rows x 16 columns]

# %%
# Total number of unique domains in PRDBv3.0
print(f"Number of unique domains in PRDBv3: {prdbv3_read_json['C_PDB'].nunique()}\n")
# Number of unique PDB ID in each structural class
print(f"Number of unique PDB ID in each structural class:\n{prdbv3_read_json['Structural_class'].value_counts()}\n")
# Number of unique PDB ID in each flexible class
print(f"Number of unique PDB ID in each flexible class:\n{prdbv3_read_json['Flexible_class'].value_counts()}\n")
# Number of unique PDB ID in each docking case
print(f"Number of unique PDB ID in each docking case:\n{prdbv3_read_json['Docking_case'].value_counts()}\n")
# Out:
# Number of unique domains in PRDBv3: 197
#
# Number of unique PDB ID in each structural class:
# Structural_class
# D    86
# C    62
# A    40
# B     9
# Name: count, dtype: int64
#
# Number of unique PDB ID in each flexible class:
# Flexible_class
# R    117
# S     41
# F     29
# Name: count, dtype: int64
#
# Number of unique PDB ID in each docking case:
# Docking_case
# UB    160
# UU     27
# BU     10
# Name: count, dtype: int64

# %% [markdown]
# ## Read PDB files from PRDBv3.0 dataset

# %%
# PRDBv3 dataset directory
PRDBv3_dir = "/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0"

# %% [markdown]
# ### PRDBv3.0: List only directories from different classes

# %%
# List only directories
# List only directories in different classes
for root, dirs, files in os.walk(PRDBv3_dir):
    for dir in dirs:
        if dir in prdbv3_read_json.C_PDB.values:
            print(os.path.join(root, dir))
# Out:
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6HTU
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1JBS
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2PY9
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2GJW
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2AZ0
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6L1W
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2GIC
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1SDS
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1J1U
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1K8W
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2GXB
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1M5O
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5EX7
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3MOJ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6HAU
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BTE
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2OZB
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7ZLQ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1QTQ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4ZT0
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4H5P
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1N35
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1M8V
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8TG4
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3FTE
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7OG0
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7K98
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BGG
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8DZK
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2QUX
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1VFG
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6L5N
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2A8V
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4QU6
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1LNG
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1B23
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2R7R
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3OL6
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3EQT
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1YVP
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8JOZ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3BX2
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5DET
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3O8C
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5X6B
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2FMT
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WWX
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5EIM
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6ZOT
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1H4S
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3A6P
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7KL3
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZM5
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2F8S
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1QF6
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7VSJ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7C45
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3ZC0
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1G2E
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6LLB
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6R9P
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3SNP
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6ZDP
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1AV6
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WPU
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7EIU
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1FEU
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5GXH
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3PF4
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7K5L
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8AF0
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1OOA
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1C9S
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1UVI
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4MDX
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2PJP
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6LT7
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7KKV
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3D2S
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3NMR
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3O3I
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ASB
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZZM
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3HL2
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3ADB
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4N2Q
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6FQ3
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5T8Y
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1CVJ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1JID
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5W0M
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2XNR
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5V7C
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1U0B
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3RC8
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7YSE
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1Q2R
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2EZ6
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ZBI
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WTY
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7L6T
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1KQ2
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7XWZ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4YCP
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4IG8
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7V4G
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7KFN
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2Q66
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1HQ1
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3MDG
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6DCB
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1G1X
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8AXF
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3IEV
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6A4E
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ED1
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6WXY
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7Y7Q
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6U9X
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1C0A
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WTK
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5SZE
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZSC
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6I0V
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4ERD
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1H3E
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4HOR
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2R8S
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2HW8
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5B63
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ASY
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3VJR
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2Y8W
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3QJJ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4YVJ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6D12
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2JEA
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZQ8
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZKO
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WSU
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2DRB
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2I82
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6U6Y
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3DD2
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3AEV
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3ZJT
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7VKL
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6AAX
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7DOL
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WT1
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4J7M
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3OIJ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1SER
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4E78
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5F5H
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2FK6
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1F7U
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3BSN
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5HR7
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8H1B
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1M8W
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7P0V
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7E8O
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2XGJ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2IX1
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6PZQ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3BT7
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6A6J
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6GC5
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BH2
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1DFU
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2JLU
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4FVU
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7VKI
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1MMS
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8EDJ
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7MJW
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZW4
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4ILL
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ZBH
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5LTA
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6LVR
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4M59
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2XZO
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2AZX
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7XD8
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1R3E
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3AMT
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6SY4
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6RTI
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WNE
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3RW6
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3KS8
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1MSW
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1N78
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ELS
# /home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7OM6

# %% [markdown]
# ### PRDBv3.0: List all files with directories

# %%
def get_PRDBv3_info(path, df_to_parse):
    print(f'INFO PRDBv3:\nTotal {len(df_to_parse)} directories in dataframe: \n')
    # Iterate through each directory in the PRDBv3 dataset directory
    count_dir = 1
    for pdbdir in df_to_parse['C_PDB'].values:
        try:
            print(f'({count_dir}) Directory path:{os.path.join(path, pdbdir)}')
            print(f'Total {len(os.listdir(os.path.join(path, pdbdir)))} PDB files in {pdbdir} directory.')
            print(f'All files in {pdbdir} directory:\n{os.listdir(os.path.join(path, pdbdir))}\n')
            count_dir += 1
            # Catch exception for directories not found
        except:
            print(f'Directory not found: {os.path.join(path, pdbdir)}\n')
# Read directories, files and its contents in PRDBv3 dataset directory
get_PRDBv3_info(PRDBv3_dir, prdbv3_read_json)
# Out:
# INFO PRDBv3:
# Total 197 directories in dataframe:
#
# (1) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ASY
# Total 8 PDB files in 1ASY directory.
# All files in 1ASY directory:
# ['2TRA.pdb', '1EOV.pdb', '1ASY_1EOV.pdb', '2TRA_mod.pdb', '1ASY_mod.pdb', '1ASY_2TRA.pdb', '1ASY.pdb', '1EOV_mod.pdb']
#
# (2) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1B23
# Total 8 PDB files in 1B23 directory.
# All files in 1B23 directory:
# ['1TUI_mod.pdb', '1B23.pdb', '1TUI.pdb', '1U0B.pdb', '1B23_mod.pdb', '1U0B_mod.pdb', '1B23_1TUI.pdb', '1B23_1U0B.pdb']
#
# (3) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1C0A
# Total 8 PDB files in 1C0A directory.
# All files in 1C0A directory:
# ['1C0A_1EQR.pdb', '1C0A.pdb', '1EQR_mod.pdb', '1C0A_1EFW.pdb', '1EFW.pdb', '1EFW_mod.pdb', '1C0A_mod.pdb', '1EQR.pdb']
#
# (4) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1QTQ
# Total 8 PDB files in 1QTQ directory.
# All files in 1QTQ directory:
# ['1QTQ_mod.pdb', '1NYL.pdb', '1QTQ.pdb', '1QTQ_3KNH.pdb', '3KNH_mod.pdb', '3KNH.pdb', '1NYL_mod.pdb', '1QTQ_1NYL.pdb']
#
# (5) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BTE
# Total 8 PDB files in 2BTE directory.
# All files in 2BTE directory:
# ['2NQP_mod.pdb', '2BTE_1OBC.pdb', '2NQP.pdb', '1OBC.pdb', '1OBC_mod.pdb', '2BTE.pdb', '2BTE_2NQP.pdb', '2BTE_mod.pdb']
#
# (6) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2DRB
# Total 8 PDB files in 2DRB directory.
# All files in 2DRB directory:
# ['1UET.pdb', '2DRB.pdb', '3Q1Q_mod.pdb', '3Q1Q.pdb', '2DRB_1UET.pdb', '2DRB_3Q1Q.pdb', '2DRB_mod.pdb', '1UET_mod.pdb']
#
# (7) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2FMT
# Total 8 PDB files in 2FMT directory.
# All files in 2FMT directory:
# ['1FMT.pdb', '3CW6.pdb', '2FMT_3CW6.pdb', '2FMT_1FMT.pdb', '2FMT_mod.pdb', '2FMT.pdb', '1FMT_mod.pdb', '3CW6_mod.pdb']
#
# (8) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZZM
# Total 8 PDB files in 2ZZM directory.
# All files in 2ZZM directory:
# ['2ZZM_mod.pdb', '2YX1.pdb', '2YX1_mod.pdb', '1WZ2.pdb', '2ZZM_1WZ2.pdb', '2ZZM.pdb', '2ZZM_2YX1.pdb', '1WZ2_mod.pdb']
#
# (9) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3HL2
# Total 8 PDB files in 3HL2 directory.
# All files in 3HL2 directory:
# ['3RG5_mod.pdb', '3HL2_mod.pdb', '3RG5.pdb', '3BC8_mod.pdb', '3HL2_3RG5.pdb', '3HL2.pdb', '3HL2_3BC8.pdb', '3BC8.pdb']
#
# (10) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3VJR
# Total 8 PDB files in 3VJR directory.
# All files in 3VJR directory:
# ['2PTH_mod.pdb', '1NJM_mod.pdb', '3VJR_mod.pdb', '3VJR_1NJM.pdb', '1NJM.pdb', '3VJR_2PTH.pdb', '2PTH.pdb', '3VJR.pdb']
#
# (11) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5X6B
# Total 8 PDB files in 5X6B directory.
# All files in 5X6B directory:
# ['5X6B.pdb', '2ZZN_mod.pdb', '5X6B_mod.pdb', '2ZZN.pdb', '5X6B_2ZZN.pdb', '5X6B_3WKR.pdb', '3WKR.pdb', '3WKR_mod.pdb']
#
# (12) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6LVR
# Total 8 PDB files in 6LVR directory.
# All files in 6LVR directory:
# ['4G24_mod.pdb', '6LVR.pdb', '1I9V_mod.pdb', '4G24.pdb', '1I9V.pdb', '6LVR_mod.pdb', '6LVR_4G24.pdb', '6LVR_1I9V.pdb']
#
# (13) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7YSE
# Total 8 PDB files in 7YSE directory.
# All files in 7YSE directory:
# ['7EIV.pdb', '7YSE_7EIV.pdb', '7YSE.pdb', '7EIV_mod.pdb', '7F36_mod.pdb', '7YSE_mod.pdb', '7F36.pdb', '7YSE_7F36.pdb']
#
# (14) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1DFU
# Total 8 PDB files in 1DFU directory.
# All files in 1DFU directory:
# ['1DFU_mod.pdb', '364D.pdb', '364D_mod.pdb', '1DFU_364D.pdb', '1B75.pdb', '1B75_mod.pdb', '1DFU_1B75.pdb', '1DFU.pdb']
#
# (15) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1FEU
# Total 8 PDB files in 1FEU directory.
# All files in 1FEU directory:
# ['364D.pdb', '364D_mod.pdb', '2J01.pdb', '1FEU.pdb', '2J01_mod.pdb', '1FEU_364D.pdb', '1FEU_mod.pdb', '1FEU_2J01.pdb']
#
# (16) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1MMS
# Total 8 PDB files in 1MMS directory.
# All files in 1MMS directory:
# ['1MMS_2K3F.pdb', '3I9C.pdb', '2K3F_mod.pdb', '1MMS_mod.pdb', '1MMS.pdb', '3I9C_mod.pdb', '2K3F.pdb', '1MMS_3I9C.pdb']
#
# (17) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3IEV
# Total 8 PDB files in 3IEV directory.
# All files in 3IEV directory:
# ['3IEV.pdb', '1SDR_mod.pdb', '3IEV_mod.pdb', '1SDR.pdb', '7C1O_mod.pdb', '3IEV_7C1O.pdb', '7C1O.pdb', '3IEV_1SDR.pdb']
#
# (18) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1OOA
# Total 8 PDB files in 1OOA directory.
# All files in 1OOA directory:
# ['1LE5_mod.pdb', '1LE5.pdb', '2JWV.pdb', '1OOA_mod.pdb', '2JWV_mod.pdb', '1OOA_2JWV.pdb', '1OOA.pdb', '1OOA_1LE5.pdb']
#
# (19) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1R3E
# Total 8 PDB files in 1R3E directory.
# All files in 1R3E directory:
# ['1EHZ_mod.pdb', '1ZE1.pdb', '1R3E.pdb', '1R3E_1ZE1.pdb', '1ZE1_mod.pdb', '1EHZ.pdb', '1R3E_1EHZ.pdb', '1R3E_mod.pdb']
#
# (20) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2R8S
# Total 8 PDB files in 2R8S directory.
# All files in 2R8S directory:
# ['1HR2.pdb', '2HFF.pdb', '2HFF_mod.pdb', '2R8S_2HFF.pdb', '2R8S.pdb', '2R8S_1HR2.pdb', '2R8S_mod.pdb', '1HR2_mod.pdb']
#
# (21) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3SNP
# Total 8 PDB files in 3SNP directory.
# All files in 3SNP directory:
# ['3SNP_mod.pdb', '3SNP_2B3Y.pdb', '1AQO.pdb', '3SNP.pdb', '2B3Y_mod.pdb', '3SNP_1AQO.pdb', '2B3Y.pdb', '1AQO_mod.pdb']
#
# (22) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2OZB
# Total 8 PDB files in 2OZB directory.
# All files in 2OZB directory:
# ['2OZB_2JNB.pdb', '2OZB_2XEB.pdb', '2JNB_mod.pdb', '2XEB.pdb', '2OZB_mod.pdb', '2JNB.pdb', '2XEB_mod.pdb', '2OZB.pdb']
#
# (23) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7P0V
# Total 8 PDB files in 7P0V directory.
# All files in 7P0V directory:
# ['7P0V.pdb', '8ID2_mod.pdb', '7P08.pdb', '7P0V_mod.pdb', '7P0V_8ID2.pdb', '7P08_mod.pdb', '7P0V_7P08.pdb', '8ID2.pdb']
#
# (24) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1JBS
# Total 8 PDB files in 1JBS directory.
# All files in 1JBS directory:
# ['1Q9A.pdb', '1Q9A_mod.pdb', '1JBS_1Q9A.pdb', '1JBS_1AQZ.pdb', '1AQZ.pdb', '1JBS.pdb', '1AQZ_mod.pdb', '1JBS_mod.pdb']
#
# (25) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WSU
# Total 8 PDB files in 1WSU directory.
# All files in 1WSU directory:
# ['1WSU_mod.pdb', '1WSU_2RLU.pdb', '1LVA_mod.pdb', '2RLU_mod.pdb', '1WSU.pdb', '1LVA.pdb', '1WSU_1LVA.pdb', '2RLU.pdb']
#
# (26) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ZBH
# Total 8 PDB files in 1ZBH directory.
# All files in 1ZBH directory:
# ['1ZBH.pdb', '1JU7.pdb', '1ZBH_1ZBU.pdb', '1JU7_mod.pdb', '1ZBH_mod.pdb', '1ZBH_1JU7.pdb', '1ZBU_mod.pdb', '1ZBU.pdb']
#
# (27) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BH2
# Total 8 PDB files in 2BH2 directory.
# All files in 2BH2 directory:
# ['2BH2_1UWV.pdb', '1UWV.pdb', '1UWV_mod.pdb', '2BH2_mod.pdb', '1JZX.pdb', '2BH2.pdb', '1JZX_mod.pdb', '2BH2_1JZX.pdb']
#
# (28) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1F7U
# Total 5 PDB files in 1F7U directory.
# All files in 1F7U directory:
# ['1F7U_1BS2.pdb', '1F7U.pdb', '1BS2.pdb', '1F7U_mod.pdb', '1BS2_mod.pdb']
#
# (29) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1H3E
# Total 5 PDB files in 1H3E directory.
# All files in 1H3E directory:
# ['1H3F_mod.pdb', '1H3E_mod.pdb', '1H3E.pdb', '1H3E_1H3F.pdb', '1H3F.pdb']
#
# (30) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1H4S
# Total 5 PDB files in 1H4S directory.
# All files in 1H4S directory:
# ['1H4S_mod.pdb', '1H4S.pdb', '1H4S_1HC7.pdb', '1HC7_mod.pdb', '1HC7.pdb']
#
# (31) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1J1U
# Total 5 PDB files in 1J1U directory.
# All files in 1J1U directory:
# ['1J1U_1U7D.pdb', '1U7D.pdb', '1U7D_mod.pdb', '1J1U.pdb', '1J1U_mod.pdb']
#
# (32) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1N78
# Total 5 PDB files in 1N78 directory.
# All files in 1N78 directory:
# ['1N78.pdb', '1J09_mod.pdb', '1N78_mod.pdb', '1N78_1J09.pdb', '1J09.pdb']
#
# (33) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1QF6
# Total 5 PDB files in 1QF6 directory.
# All files in 1QF6 directory:
# ['1QF6_mod.pdb', '1EVL_mod.pdb', '1QF6.pdb', '1EVL.pdb', '1QF6_1EVL.pdb']
#
# (34) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1SER
# Total 5 PDB files in 1SER directory.
# All files in 1SER directory:
# ['1SER_1SES.pdb', '1SER.pdb', '1SES_mod.pdb', '1SER_mod.pdb', '1SES.pdb']
#
# (35) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1U0B
# Total 5 PDB files in 1U0B directory.
# All files in 1U0B directory:
# ['1U0B_1LI5.pdb', '1LI5_mod.pdb', '1LI5.pdb', '1U0B.pdb', '1U0B_mod.pdb']
#
# (36) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1VFG
# Total 5 PDB files in 1VFG directory.
# All files in 1VFG directory:
# ['4WBY_mod.pdb', '4WBY.pdb', '1VFG_4WBY.pdb', '1VFG_mod.pdb', '1VFG.pdb']
#
# (37) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2AZX
# Total 5 PDB files in 2AZX directory.
# All files in 2AZX directory:
# ['2AZX_1R6U.pdb', '2AZX_mod.pdb', '1R6U_mod.pdb', '2AZX.pdb', '1R6U.pdb']
#
# (38) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2FK6
# Total 5 PDB files in 2FK6 directory.
# All files in 2FK6 directory:
# ['1Y44_mod.pdb', '1Y44.pdb', '2FK6_mod.pdb', '2FK6.pdb', '2FK6_1Y44.pdb']
#
# (39) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3ADB
# Total 5 PDB files in 3ADB directory.
# All files in 3ADB directory:
# ['3ADB.pdb', '3A4M_mod.pdb', '3A4M.pdb', '3ADB_3A4M.pdb', '3ADB_mod.pdb']
#
# (40) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3AMT
# Total 5 PDB files in 3AMT directory.
# All files in 3AMT directory:
# ['3AU7.pdb', '3AMT_3AU7.pdb', '3AU7_mod.pdb', '3AMT.pdb', '3AMT_mod.pdb']
#
# (41) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4YCP
# Total 5 PDB files in 4YCP directory.
# All files in 4YCP directory:
# ['4YCP_mod.pdb', '4YCP.pdb', '4BFA.pdb', '4YCP_4BFA.pdb', '4BFA_mod.pdb']
#
# (42) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4YVJ
# Total 5 PDB files in 4YVJ directory.
# All files in 4YVJ directory:
# ['4YVJ_mod.pdb', '3AXZ_mod.pdb', '4YVJ_3AXZ.pdb', '3AXZ.pdb', '4YVJ.pdb']
#
# (43) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5HR7
# Total 5 PDB files in 5HR7 directory.
# All files in 5HR7 directory:
# ['5HR7.pdb', '5HR7_mod.pdb', '3RFA_mod.pdb', '3RFA.pdb', '5HR7_3RFA.pdb']
#
# (44) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5B63
# Total 5 PDB files in 5B63 directory.
# All files in 5B63 directory:
# ['5B63_5YYM.pdb', '5YYM.pdb', '5B63_mod.pdb', '5YYM_mod.pdb', '5B63.pdb']
#
# (45) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5T8Y
# Total 5 PDB files in 5T8Y directory.
# All files in 5T8Y directory:
# ['5D08_mod.pdb', '5T8Y_5D08.pdb', '5T8Y.pdb', '5D08.pdb', '5T8Y_mod.pdb']
#
# (46) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WT1
# Total 5 PDB files in 5WT1 directory.
# All files in 5WT1 directory:
# ['5WT1.pdb', '5WT1_5HJI.pdb', '5HJI.pdb', '5WT1_mod.pdb', '5HJI_mod.pdb']
#
# (47) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZW4
# Total 5 PDB files in 5ZW4 directory.
# All files in 5ZW4 directory:
# ['5ZW3_mod.pdb', '5ZW4_mod.pdb', '5ZW4_5ZW3.pdb', '5ZW3.pdb', '5ZW4.pdb']
#
# (48) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7E8O
# Total 5 PDB files in 7E8O directory.
# All files in 7E8O directory:
# ['7E8O_7E8K.pdb', '7E8K.pdb', '7E8O.pdb', '7E8O_mod.pdb', '7E8K_mod.pdb']
#
# (49) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7K98
# Total 5 PDB files in 7K98 directory.
# All files in 7K98 directory:
# ['7DAW_mod.pdb', '7K98_mod.pdb', '7K98_7DAW.pdb', '7DAW.pdb', '7K98.pdb']
#
# (50) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7MJW
# Total 5 PDB files in 7MJW directory.
# All files in 7MJW directory:
# ['7MJW_mod.pdb', '7MJZ_mod.pdb', '7MJZ.pdb', '7MJW_7MJZ.pdb', '7MJW.pdb']
#
# (51) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8H1B
# Total 5 PDB files in 8H1B directory.
# All files in 8H1B directory:
# ['8H1B_mod.pdb', '8H1A.pdb', '8H1A_mod.pdb', '8H1B_8H1A.pdb', '8H1B.pdb']
#
# (52) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8JOZ
# Total 5 PDB files in 8JOZ directory.
# All files in 8JOZ directory:
# ['8JOZ_4HTF.pdb', '4HTF_mod.pdb', '4HTF.pdb', '8JOZ.pdb', '8JOZ_mod.pdb']
#
# (53) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1G1X
# Total 5 PDB files in 1G1X directory.
# All files in 1G1X directory:
# ['1G1X_mod.pdb', '1G1X.pdb', '1CQM.pdb', '1CQM_mod.pdb', '1G1X_1CQM.pdb']
#
# (54) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1SDS
# Total 5 PDB files in 1SDS directory.
# All files in 1SDS directory:
# ['1SDS_1XBI.pdb', '1XBI.pdb', '1SDS.pdb', '1SDS_mod.pdb', '1XBI_mod.pdb']
#
# (55) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2HW8
# Total 5 PDB files in 2HW8 directory.
# All files in 2HW8 directory:
# ['2HW8_mod.pdb', '2HW8.pdb', '1AD2_mod.pdb', '2HW8_1AD2.pdb', '1AD2.pdb']
#
# (56) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WTY
# Total 5 PDB files in 5WTY directory.
# All files in 5WTY directory:
# ['5WTY_mod.pdb', '5SVD_mod.pdb', '5WTY.pdb', '5WTY_5SVD.pdb', '5SVD.pdb']
#
# (57) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1MSW
# Total 5 PDB files in 1MSW directory.
# All files in 1MSW directory:
# ['1MSW_1ARO.pdb', '1MSW.pdb', '1MSW_mod.pdb', '1ARO_mod.pdb', '1ARO.pdb']
#
# (58) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1N35
# Total 5 PDB files in 1N35 directory.
# All files in 1N35 directory:
# ['1MUK.pdb', '1N35_1MUK.pdb', '1MUK_mod.pdb', '1N35.pdb', '1N35_mod.pdb']
#
# (59) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1Q2R
# Total 5 PDB files in 1Q2R directory.
# All files in 1Q2R directory:
# ['1R5Y_mod.pdb', '1R5Y.pdb', '1Q2R_1R5Y.pdb', '1Q2R_mod.pdb', '1Q2R.pdb']
#
# (60) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WNE
# Total 5 PDB files in 1WNE directory.
# All files in 1WNE directory:
# ['1WNE_mod.pdb', '1U09_mod.pdb', '1U09.pdb', '1WNE.pdb', '1WNE_1U09.pdb']
#
# (61) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1YVP
# Total 5 PDB files in 1YVP directory.
# All files in 1YVP directory:
# ['1YVP_1YVR.pdb', '1YVR.pdb', '1YVP_mod.pdb', '1YVR_mod.pdb', '1YVP.pdb']
#
# (62) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ZBI
# Total 5 PDB files in 1ZBI directory.
# All files in 1ZBI directory:
# ['1ZBI_mod.pdb', '1ZBF.pdb', '1ZBI.pdb', '1ZBF_mod.pdb', '1ZBI_1ZBF.pdb']
#
# (63) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2AZ0
# Total 5 PDB files in 2AZ0 directory.
# All files in 2AZ0 directory:
# ['2B9Z_mod.pdb', '2B9Z.pdb', '2AZ0_2B9Z.pdb', '2AZ0_mod.pdb', '2AZ0.pdb']
#
# (64) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BGG
# Total 5 PDB files in 2BGG directory.
# All files in 2BGG directory:
# ['1W9H_mod.pdb', '2BGG_1W9H.pdb', '1W9H.pdb', '2BGG_mod.pdb', '2BGG.pdb']
#
# (65) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2EZ6
# Total 5 PDB files in 2EZ6 directory.
# All files in 2EZ6 directory:
# ['1JFZ_mod.pdb', '2EZ6.pdb', '1JFZ.pdb', '2EZ6_mod.pdb', '2EZ6_1JFZ.pdb']
#
# (66) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2F8S
# Total 5 PDB files in 2F8S directory.
# All files in 2F8S directory:
# ['2F8S_1YVU.pdb', '2F8S_mod.pdb', '1YVU_mod.pdb', '1YVU.pdb', '2F8S.pdb']
#
# (67) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2GJW
# Total 5 PDB files in 2GJW directory.
# All files in 2GJW directory:
# ['1R0V_mod.pdb', '2GJW.pdb', '1R0V.pdb', '2GJW_1R0V.pdb', '2GJW_mod.pdb']
#
# (68) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2GXB
# Total 5 PDB files in 2GXB directory.
# All files in 2GXB directory:
# ['2GXB.pdb', '1QGP.pdb', '2GXB_1QGP.pdb', '2GXB_mod.pdb', '1QGP_mod.pdb']
#
# (69) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2QUX
# Total 5 PDB files in 2QUX directory.
# All files in 2QUX directory:
# ['2QUX_mod.pdb', '2QUD_mod.pdb', '2QUX_2QUD.pdb', '2QUX.pdb', '2QUD.pdb']
#
# (70) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2Y8W
# Total 5 PDB files in 2Y8W directory.
# All files in 2Y8W directory:
# ['2Y8W_mod.pdb', '1WJ9.pdb', '1WJ9_mod.pdb', '2Y8W_1WJ9.pdb', '2Y8W.pdb']
#
# (71) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZKO
# Total 5 PDB files in 2ZKO directory.
# All files in 2ZKO directory:
# ['2Z0A.pdb', '2ZKO_mod.pdb', '2Z0A_mod.pdb', '2ZKO_2Z0A.pdb', '2ZKO.pdb']
#
# (72) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3A6P
# Total 5 PDB files in 3A6P directory.
# All files in 3A6P directory:
# ['3A6P.pdb', '3A6P_mod.pdb', '3A6P_5YU6.pdb', '5YU6.pdb', '5YU6_mod.pdb']
#
# (73) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3BSN
# Total 5 PDB files in 3BSN directory.
# All files in 3BSN directory:
# ['3BSN_mod.pdb', '3BSN.pdb', '1SH3.pdb', '3BSN_1SH3.pdb', '1SH3_mod.pdb']
#
# (74) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3DD2
# Total 5 PDB files in 3DD2 directory.
# All files in 3DD2 directory:
# ['3DD2_mod.pdb', '1JOU.pdb', '1JOU_mod.pdb', '3DD2.pdb', '3DD2_1JOU.pdb']
#
# (75) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3EQT
# Total 5 PDB files in 3EQT directory.
# All files in 3EQT directory:
# ['2W4R_mod.pdb', '2W4R.pdb', '3EQT_2W4R.pdb', '3EQT_mod.pdb', '3EQT.pdb']
#
# (76) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3FTE
# Total 5 PDB files in 3FTE directory.
# All files in 3FTE directory:
# ['3FTE_3FTD.pdb', '3FTE_mod.pdb', '3FTD.pdb', '3FTE.pdb', '3FTD_mod.pdb']
#
# (77) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3KS8
# Total 5 PDB files in 3KS8 directory.
# All files in 3KS8 directory:
# ['3KS8.pdb', '3KS4_mod.pdb', '3KS4.pdb', '3KS8_3KS4.pdb', '3KS8_mod.pdb']
#
# (78) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3MOJ
# Total 5 PDB files in 3MOJ directory.
# All files in 3MOJ directory:
# ['3MOJ.pdb', '3MOJ_2G0C.pdb', '2G0C.pdb', '2G0C_mod.pdb', '3MOJ_mod.pdb']
#
# (79) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3O3I
# Total 5 PDB files in 3O3I directory.
# All files in 3O3I directory:
# ['3O3I.pdb', '3O3I_mod.pdb', '2L5C.pdb', '2L5C_mod.pdb', '3O3I_2L5C.pdb']
#
# (80) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3OIJ
# Total 5 PDB files in 3OIJ directory.
# All files in 3OIJ directory:
# ['3OIJ_3OII.pdb', '3OII_mod.pdb', '3OII.pdb', '3OIJ.pdb', '3OIJ_mod.pdb']
#
# (81) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3OL6
# Total 5 PDB files in 3OL6 directory.
# All files in 3OL6 directory:
# ['3OL6.pdb', '3OL6_mod.pdb', '1RA6_mod.pdb', '3OL6_1RA6.pdb', '1RA6.pdb']
#
# (82) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3RW6
# Total 5 PDB files in 3RW6 directory.
# All files in 3RW6 directory:
# ['3RW6.pdb', '3RW6_3RW7.pdb', '3RW6_mod.pdb', '3RW7_mod.pdb', '3RW7.pdb']
#
# (83) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3ZC0
# Total 5 PDB files in 3ZC0 directory.
# All files in 3ZC0 directory:
# ['3ZC0_mod.pdb', '3ZC1.pdb', '3ZC0.pdb', '3ZC0_3ZC1.pdb', '3ZC1_mod.pdb']
#
# (84) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4ERD
# Total 5 PDB files in 4ERD directory.
# All files in 4ERD directory:
# ['4EYT.pdb', '4EYT_mod.pdb', '4ERD.pdb', '4ERD_4EYT.pdb', '4ERD_mod.pdb']
#
# (85) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4FVU
# Total 5 PDB files in 4FVU directory.
# All files in 4FVU directory:
# ['4FVU_mod.pdb', '4FVU_3Q7C.pdb', '4FVU.pdb', '3Q7C_mod.pdb', '3Q7C.pdb']
#
# (86) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4IG8
# Total 5 PDB files in 4IG8 directory.
# All files in 4IG8 directory:
# ['4IG8_1PX5.pdb', '1PX5.pdb', '1PX5_mod.pdb', '4IG8.pdb', '4IG8_mod.pdb']
#
# (87) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4ILL
# Total 5 PDB files in 4ILL directory.
# All files in 4ILL directory:
# ['4ILL_mod.pdb', '4ILL.pdb', '4ILL_4ILR.pdb', '4ILR.pdb', '4ILR_mod.pdb']
#
# (88) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4ZT0
# Total 5 PDB files in 4ZT0 directory.
# All files in 4ZT0 directory:
# ['4ZT0.pdb', '4CMP.pdb', '4ZT0_mod.pdb', '4ZT0_4CMP.pdb', '4CMP_mod.pdb']
#
# (89) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ED1
# Total 5 PDB files in 5ED1 directory.
# All files in 5ED1 directory:
# ['5ED1_mod.pdb', '1ZY7.pdb', '1ZY7_mod.pdb', '5ED1.pdb', '5ED1_1ZY7.pdb']
#
# (90) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5F5H
# Total 5 PDB files in 5F5H directory.
# All files in 5F5H directory:
# ['5F5H.pdb', '5F5H_mod.pdb', '4QI0_mod.pdb', '5F5H_4QI0.pdb', '4QI0.pdb']
#
# (91) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WTK
# Total 5 PDB files in 5WTK directory.
# All files in 5WTK directory:
# ['5WTK.pdb', '5WTK_mod.pdb', '5WTJ.pdb', '5WTK_5WTJ.pdb', '5WTJ_mod.pdb']
#
# (92) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZQ8
# Total 5 PDB files in 5ZQ8 directory.
# All files in 5ZQ8 directory:
# ['5ZQ8_mod.pdb', '5ZQ8_5XJ1.pdb', '5XJ1.pdb', '5ZQ8.pdb', '5XJ1_mod.pdb']
#
# (93) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6D12
# Total 5 PDB files in 6D12 directory.
# All files in 6D12 directory:
# ['5KNW_mod.pdb', '5KNW.pdb', '6D12_mod.pdb', '6D12.pdb', '6D12_5KNW.pdb']
#
# (94) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6DCB
# Total 5 PDB files in 6DCB directory.
# All files in 6DCB directory:
# ['6DCB_mod.pdb', '5UNA.pdb', '6DCB_5UNA.pdb', '5UNA_mod.pdb', '6DCB.pdb']
#
# (95) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6FQ3
# Total 5 PDB files in 6FQ3 directory.
# All files in 6FQ3 directory:
# ['6FQ3.pdb', '6FPT_mod.pdb', '6FPT.pdb', '6FQ3_mod.pdb', '6FQ3_6FPT.pdb']
#
# (96) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6SY4
# Total 5 PDB files in 6SY4 directory.
# All files in 6SY4 directory:
# ['3ZQI.pdb', '6SY4_mod.pdb', '6SY4_3ZQI.pdb', '3ZQI_mod.pdb', '6SY4.pdb']
#
# (97) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6PZQ
# Total 5 PDB files in 6PZQ directory.
# All files in 6PZQ directory:
# ['6G0Y.pdb', '6G0Y_mod.pdb', '6PZQ_6G0Y.pdb', '6PZQ.pdb', '6PZQ_mod.pdb']
#
# (98) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6RTI
# Total 5 PDB files in 6RTI directory.
# All files in 6RTI directory:
# ['2C6C_mod.pdb', '6RTI.pdb', '6RTI_2C6C.pdb', '6RTI_mod.pdb', '2C6C.pdb']
#
# (99) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6ZDP
# Total 5 PDB files in 6ZDP directory.
# All files in 6ZDP directory:
# ['6ZD6_mod.pdb', '6ZD6.pdb', '6ZDP_mod.pdb', '6ZDP.pdb', '6ZDP_6ZD6.pdb']
#
# (100) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7KFN
# Total 5 PDB files in 7KFN directory.
# All files in 7KFN directory:
# ['1ZY7.pdb', '1ZY7_mod.pdb', '7KFN_1ZY7.pdb', '7KFN.pdb', '7KFN_mod.pdb']
#
# (101) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7KKV
# Total 5 PDB files in 7KKV directory.
# All files in 7KKV directory:
# ['7K9B.pdb', '7K9B_mod.pdb', '7KKV_mod.pdb', '7KKV_7K9B.pdb', '7KKV.pdb']
#
# (102) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7OG0
# Total 5 PDB files in 7OG0 directory.
# All files in 7OG0 directory:
# ['7OG0.pdb', '8TV8_mod.pdb', '7OG0_mod.pdb', '8TV8.pdb', '7OG0_8TV8.pdb']
#
# (103) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7OM6
# Total 5 PDB files in 7OM6 directory.
# All files in 7OM6 directory:
# ['7OM6_mod.pdb', '7OM6_7OM2.pdb', '7OM2_mod.pdb', '7OM6.pdb', '7OM2.pdb']
#
# (104) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7XD8
# Total 5 PDB files in 7XD8 directory.
# All files in 7XD8 directory:
# ['7XD8.pdb', '6KR2.pdb', '6KR2_mod.pdb', '7XD8_mod.pdb', '7XD8_6KR2.pdb']
#
# (105) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7XWZ
# Total 5 PDB files in 7XWZ directory.
# All files in 7XWZ directory:
# ['7XWZ_mod.pdb', '7VNU.pdb', '7XWZ_7VNU.pdb', '7VNU_mod.pdb', '7XWZ.pdb']
#
# (106) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7ZLQ
# Total 5 PDB files in 7ZLQ directory.
# All files in 7ZLQ directory:
# ['7ZLQ_mod.pdb', '2MDR.pdb', '2MDR_mod.pdb', '7ZLQ.pdb', '7ZLQ_2MDR.pdb']
#
# (107) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8AF0
# Total 5 PDB files in 8AF0 directory.
# All files in 8AF0 directory:
# ['8AF0_mod.pdb', '8AF0.pdb', '5M9T_mod.pdb', '8AF0_5M9T.pdb', '5M9T.pdb']
#
# (108) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1AV6
# Total 5 PDB files in 1AV6 directory.
# All files in 1AV6 directory:
# ['1AV6_mod.pdb', '1AV6.pdb', '1AV6_1B42.pdb', '1B42_mod.pdb', '1B42.pdb']
#
# (109) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1C9S
# Total 5 PDB files in 1C9S directory.
# All files in 1C9S directory:
# ['2EXT.pdb', '1C9S.pdb', '1C9S_2EXT.pdb', '2EXT_mod.pdb', '1C9S_mod.pdb']
#
# (110) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1CVJ
# Total 5 PDB files in 1CVJ directory.
# All files in 1CVJ directory:
# ['4F25_mod.pdb', '4F25.pdb', '1CVJ_mod.pdb', '1CVJ.pdb', '1CVJ_4F25.pdb']
#
# (111) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1G2E
# Total 5 PDB files in 1G2E directory.
# All files in 1G2E directory:
# ['1G2E_mod.pdb', '4EGL.pdb', '1G2E_4EGL.pdb', '1G2E.pdb', '4EGL_mod.pdb']
#
# (112) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1K8W
# Total 5 PDB files in 1K8W directory.
# All files in 1K8W directory:
# ['1R3F_mod.pdb', '1K8W_1R3F.pdb', '1K8W.pdb', '1K8W_mod.pdb', '1R3F.pdb']
#
# (113) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1KQ2
# Total 5 PDB files in 1KQ2 directory.
# All files in 1KQ2 directory:
# ['1KQ2.pdb', '1KQ1_mod.pdb', '1KQ1.pdb', '1KQ2_1KQ1.pdb', '1KQ2_mod.pdb']
#
# (114) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1M5O
# Total 5 PDB files in 1M5O directory.
# All files in 1M5O directory:
# ['1OIA.pdb', '1M5O_mod.pdb', '1OIA_mod.pdb', '1M5O_1OIA.pdb', '1M5O.pdb']
#
# (115) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1M8V
# Total 5 PDB files in 1M8V directory.
# All files in 1M8V directory:
# ['1M8V.pdb', '1M8V_mod.pdb', '1H64_mod.pdb', '1H64.pdb', '1M8V_1H64.pdb']
#
# (116) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1M8W
# Total 5 PDB files in 1M8W directory.
# All files in 1M8W directory:
# ['1M8Z_mod.pdb', '1M8W.pdb', '1M8Z.pdb', '1M8W_1M8Z.pdb', '1M8W_mod.pdb']
#
# (117) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1UVI
# Total 5 PDB files in 1UVI directory.
# All files in 1UVI directory:
# ['1HHS_mod.pdb', '1UVI.pdb', '1HHS.pdb', '1UVI_mod.pdb', '1UVI_1HHS.pdb']
#
# (118) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WPU
# Total 5 PDB files in 1WPU directory.
# All files in 1WPU directory:
# ['1WPU_mod.pdb', '1WPV.pdb', '1WPV_mod.pdb', '1WPU_1WPV.pdb', '1WPU.pdb']
#
# (119) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2A8V
# Total 5 PDB files in 2A8V directory.
# All files in 2A8V directory:
# ['1A8V.pdb', '2A8V_1A8V.pdb', '2A8V.pdb', '1A8V_mod.pdb', '2A8V_mod.pdb']
#
# (120) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ASB
# Total 5 PDB files in 2ASB directory.
# All files in 2ASB directory:
# ['2ASB_1K0R.pdb', '1K0R.pdb', '1K0R_mod.pdb', '2ASB_mod.pdb', '2ASB.pdb']
#
# (121) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2GIC
# Total 5 PDB files in 2GIC directory.
# All files in 2GIC directory:
# ['2QVJ_mod.pdb', '2GIC_mod.pdb', '2GIC.pdb', '2QVJ.pdb', '2GIC_2QVJ.pdb']
#
# (122) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2IX1
# Total 5 PDB files in 2IX1 directory.
# All files in 2IX1 directory:
# ['2IX0.pdb', '2IX0_mod.pdb', '2IX1.pdb', '2IX1_2IX0.pdb', '2IX1_mod.pdb']
#
# (123) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2JEA
# Total 5 PDB files in 2JEA directory.
# All files in 2JEA directory:
# ['2JE6_mod.pdb', '2JEA_mod.pdb', '2JEA_2JE6.pdb', '2JEA.pdb', '2JE6.pdb']
#
# (124) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2JLU
# Total 5 PDB files in 2JLU directory.
# All files in 2JLU directory:
# ['2JLU_2JLQ.pdb', '2JLU.pdb', '2JLQ.pdb', '2JLU_mod.pdb', '2JLQ_mod.pdb']
#
# (125) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2PY9
# Total 5 PDB files in 2PY9 directory.
# All files in 2PY9 directory:
# ['2PY9_2JZX.pdb', '2PY9.pdb', '2PY9_mod.pdb', '2JZX_mod.pdb', '2JZX.pdb']
#
# (126) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2Q66
# Total 5 PDB files in 2Q66 directory.
# All files in 2Q66 directory:
# ['2HHP_mod.pdb', '2Q66_2HHP.pdb', '2Q66.pdb', '2HHP.pdb', '2Q66_mod.pdb']
#
# (127) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2R7R
# Total 5 PDB files in 2R7R directory.
# All files in 2R7R directory:
# ['2R7Q_mod.pdb', '2R7R_mod.pdb', '2R7Q.pdb', '2R7R.pdb', '2R7R_2R7Q.pdb']
#
# (128) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2XGJ
# Total 5 PDB files in 2XGJ directory.
# All files in 2XGJ directory:
# ['4U4C_mod.pdb', '2XGJ_4U4C.pdb', '4U4C.pdb', '2XGJ.pdb', '2XGJ_mod.pdb']
#
# (129) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2XNR
# Total 5 PDB files in 2XNR directory.
# All files in 2XNR directory:
# ['2XNR.pdb', '2XNR_2XNQ.pdb', '2XNR_mod.pdb', '2XNQ.pdb', '2XNQ_mod.pdb']
#
# (130) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2XZO
# Total 5 PDB files in 2XZO directory.
# All files in 2XZO directory:
# ['2XZP_mod.pdb', '2XZO_mod.pdb', '2XZO_2XZP.pdb', '2XZP.pdb', '2XZO.pdb']
#
# (131) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3AEV
# Total 5 PDB files in 3AEV directory.
# All files in 3AEV directory:
# ['3AEV.pdb', '2E3U.pdb', '2E3U_mod.pdb', '3AEV_mod.pdb', '3AEV_2E3U.pdb']
#
# (132) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3BX2
# Total 5 PDB files in 3BX2 directory.
# All files in 3BX2 directory:
# ['3BX2_3BWT.pdb', '3BWT.pdb', '3BWT_mod.pdb', '3BX2.pdb', '3BX2_mod.pdb']
#
# (133) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3D2S
# Total 5 PDB files in 3D2S directory.
# All files in 3D2S directory:
# ['3D2Q_mod.pdb', '3D2S_mod.pdb', '3D2S_3D2Q.pdb', '3D2Q.pdb', '3D2S.pdb']
#
# (134) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3MDG
# Total 5 PDB files in 3MDG directory.
# All files in 3MDG directory:
# ['3MDG_3BAP.pdb', '3BAP.pdb', '3BAP_mod.pdb', '3MDG_mod.pdb', '3MDG.pdb']
#
# (135) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3NMR
# Total 5 PDB files in 3NMR directory.
# All files in 3NMR directory:
# ['3NMR_2DHS.pdb', '3NMR.pdb', '2DHS_mod.pdb', '3NMR_mod.pdb', '2DHS.pdb']
#
# (136) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3O8C
# Total 5 PDB files in 3O8C directory.
# All files in 3O8C directory:
# ['3O8B_mod.pdb', '3O8C_3O8B.pdb', '3O8C.pdb', '3O8C_mod.pdb', '3O8B.pdb']
#
# (137) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3PF4
# Total 5 PDB files in 3PF4 directory.
# All files in 3PF4 directory:
# ['1CSP_mod.pdb', '3PF4_1CSP.pdb', '3PF4_mod.pdb', '3PF4.pdb', '1CSP.pdb']
#
# (138) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3QJJ
# Total 5 PDB files in 3QJJ directory.
# All files in 3QJJ directory:
# ['3QJJ.pdb', '3QJJ_3UFC.pdb', '3UFC.pdb', '3QJJ_mod.pdb', '3UFC_mod.pdb']
#
# (139) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3RC8
# Total 5 PDB files in 3RC8 directory.
# All files in 3RC8 directory:
# ['3RC8_3RC3.pdb', '3RC8.pdb', '3RC3.pdb', '3RC3_mod.pdb', '3RC8_mod.pdb']
#
# (140) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4E78
# Total 5 PDB files in 4E78 directory.
# All files in 4E78 directory:
# ['4E78.pdb', '4E76_mod.pdb', '4E78_4E76.pdb', '4E78_mod.pdb', '4E76.pdb']
#
# (141) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4H5P
# Total 5 PDB files in 4H5P directory.
# All files in 4H5P directory:
# ['3LYF.pdb', '4H5P.pdb', '4H5P_3LYF.pdb', '4H5P_mod.pdb', '3LYF_mod.pdb']
#
# (142) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4HOR
# Total 5 PDB files in 4HOR directory.
# All files in 4HOR directory:
# ['4HOR_4HOQ.pdb', '4HOQ.pdb', '4HOQ_mod.pdb', '4HOR_mod.pdb', '4HOR.pdb']
#
# (143) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4J7M
# Total 5 PDB files in 4J7M directory.
# All files in 4J7M directory:
# ['4J7M_mod.pdb', '4J7N.pdb', '4J7M.pdb', '4J7M_4J7N.pdb', '4J7N_mod.pdb']
#
# (144) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4M59
# Total 5 PDB files in 4M59 directory.
# All files in 4M59 directory:
# ['4M57.pdb', '4M59_4M57.pdb', '4M59_mod.pdb', '4M59.pdb', '4M57_mod.pdb']
#
# (145) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4MDX
# Total 5 PDB files in 4MDX directory.
# All files in 4MDX directory:
# ['1NE8.pdb', '4MDX_1NE8.pdb', '4MDX.pdb', '4MDX_mod.pdb', '1NE8_mod.pdb']
#
# (146) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4N2Q
# Total 5 PDB files in 4N2Q directory.
# All files in 4N2Q directory:
# ['4N2Q.pdb', '4ME2_mod.pdb', '4N2Q_mod.pdb', '4ME2.pdb', '4N2Q_4ME2.pdb']
#
# (147) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4QU6
# Total 5 PDB files in 4QU6 directory.
# All files in 4QU6 directory:
# ['2LMI.pdb', '2LMI_mod.pdb', '4QU6_mod.pdb', '4QU6.pdb', '4QU6_2LMI.pdb']
#
# (148) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5DET
# Total 5 PDB files in 5DET directory.
# All files in 5DET directory:
# ['5DET_mod.pdb', '5CYJ_mod.pdb', '5DET_5CYJ.pdb', '5DET.pdb', '5CYJ.pdb']
#
# (149) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5EIM
# Total 5 PDB files in 5EIM directory.
# All files in 5EIM directory:
# ['5H8A.pdb', '5EIM.pdb', '5H8A_mod.pdb', '5EIM_5H8A.pdb', '5EIM_mod.pdb']
#
# (150) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ELS
# Total 5 PDB files in 5ELS directory.
# All files in 5ELS directory:
# ['5ELS_5EL3.pdb', '5ELS.pdb', '5ELS_mod.pdb', '5EL3_mod.pdb', '5EL3.pdb']
#
# (151) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5EX7
# Total 5 PDB files in 5EX7 directory.
# All files in 5EX7 directory:
# ['4ZLR_mod.pdb', '4ZLR.pdb', '5EX7.pdb', '5EX7_4ZLR.pdb', '5EX7_mod.pdb']
#
# (152) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5GXH
# Total 5 PDB files in 5GXH directory.
# All files in 5GXH directory:
# ['5GXH_mod.pdb', '5GXH_5TEE.pdb', '5TEE.pdb', '5TEE_mod.pdb', '5GXH.pdb']
#
# (153) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5LTA
# Total 5 PDB files in 5LTA directory.
# All files in 5LTA directory:
# ['5LTA.pdb', '5LTA_mod.pdb', '5LTA_5D0U.pdb', '5D0U.pdb', '5D0U_mod.pdb']
#
# (154) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5SZE
# Total 5 PDB files in 5SZE directory.
# All files in 5SZE directory:
# ['5SZE_mod.pdb', '5SZE_5SZD.pdb', '5SZD.pdb', '5SZE.pdb', '5SZD_mod.pdb']
#
# (155) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5V7C
# Total 5 PDB files in 5V7C directory.
# All files in 5V7C directory:
# ['5V7C.pdb', '5V7C_mod.pdb', '5V87.pdb', '5V7C_5V87.pdb', '5V87_mod.pdb']
#
# (156) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5W0M
# Total 5 PDB files in 5W0M directory.
# All files in 5W0M directory:
# ['5W0B_mod.pdb', '5W0M_5W0B.pdb', '5W0M.pdb', '5W0B.pdb', '5W0M_mod.pdb']
#
# (157) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WWX
# Total 5 PDB files in 5WWX directory.
# All files in 5WWX directory:
# ['5WWX_mod.pdb', '5WWZ.pdb', '5WWX_5WWZ.pdb', '5WWX.pdb', '5WWZ_mod.pdb']
#
# (158) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZSC
# Total 5 PDB files in 5ZSC directory.
# All files in 5ZSC directory:
# ['6IF5.pdb', '5ZSC.pdb', '5ZSC_6IF5.pdb', '6IF5_mod.pdb', '5ZSC_mod.pdb']
#
# (159) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6A4E
# Total 5 PDB files in 6A4E directory.
# All files in 6A4E directory:
# ['6A4D_mod.pdb', '6A4D.pdb', '6A4E.pdb', '6A4E_6A4D.pdb', '6A4E_mod.pdb']
#
# (160) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6A6J
# Total 5 PDB files in 6A6J directory.
# All files in 6A6J directory:
# ['6A6J_6LMS.pdb', '6LMS.pdb', '6A6J.pdb', '6A6J_mod.pdb', '6LMS_mod.pdb']
#
# (161) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6GC5
# Total 5 PDB files in 6GC5 directory.
# All files in 6GC5 directory:
# ['6GC5_6GD1.pdb', '6GC5_mod.pdb', '6GD1.pdb', '6GC5.pdb', '6GD1_mod.pdb']
#
# (162) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6HAU
# Total 6 PDB files in 6HAU directory.
# All files in 6HAU directory:
# ['6HAT_mod.pdb', '6HAU_7HAT.pdb', '6HAT.pdb', '6HAU_6HAT.pdb', '6HAU.pdb', '6HAU_mod.pdb']
#
# (163) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6I0V
# Total 5 PDB files in 6I0V directory.
# All files in 6I0V directory:
# ['6I0S_mod.pdb', '6I0V_6I0S.pdb', '6I0V.pdb', '6I0S.pdb', '6I0V_mod.pdb']
#
# (164) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6L1W
# Total 5 PDB files in 6L1W directory.
# All files in 6L1W directory:
# ['6L1W_3U9G.pdb', '6L1W.pdb', '6L1W_mod.pdb', '3U9G_mod.pdb', '3U9G.pdb']
#
# (165) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6LLB
# Total 5 PDB files in 6LLB directory.
# All files in 6LLB directory:
# ['5HAA.pdb', '6LLB_5HAA.pdb', '6LLB.pdb', '6LLB_mod.pdb', '5HAA_mod.pdb']
#
# (166) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6R9P
# Total 5 PDB files in 6R9P directory.
# All files in 6R9P directory:
# ['6R9I.pdb', '6R9P_mod.pdb', '6R9I_mod.pdb', '6R9P_6R9I.pdb', '6R9P.pdb']
#
# (167) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6U9X
# Total 5 PDB files in 6U9X directory.
# All files in 6U9X directory:
# ['6NL1_mod.pdb', '6U9X_6NL1.pdb', '6U9X_mod.pdb', '6NL1.pdb', '6U9X.pdb']
#
# (168) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6L5N
# Total 5 PDB files in 6L5N directory.
# All files in 6L5N directory:
# ['6L5N_6L5M.pdb', '6L5M_mod.pdb', '6L5N.pdb', '6L5N_mod.pdb', '6L5M.pdb']
#
# (169) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6LT7
# Total 5 PDB files in 6LT7 directory.
# All files in 6LT7 directory:
# ['6LT7.pdb', '6CWX.pdb', '6LT7_6CWX.pdb', '6LT7_mod.pdb', '6CWX_mod.pdb']
#
# (170) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6U6Y
# Total 5 PDB files in 6U6Y directory.
# All files in 6U6Y directory:
# ['6U6Y_5AO3.pdb', '5AO3_mod.pdb', '6U6Y_mod.pdb', '6U6Y.pdb', '5AO3.pdb']
#
# (171) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6WXY
# Total 5 PDB files in 6WXY directory.
# All files in 6WXY directory:
# ['6WXY_6WXW.pdb', '6WXY.pdb', '6WXY_mod.pdb', '6WXW_mod.pdb', '6WXW.pdb']
#
# (172) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6ZOT
# Total 5 PDB files in 6ZOT directory.
# All files in 6ZOT directory:
# ['8BS5.pdb', '8BS5_mod.pdb', '6ZOT_mod.pdb', '6ZOT_8BS5.pdb', '6ZOT.pdb']
#
# (173) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7C45
# Total 5 PDB files in 7C45 directory.
# All files in 7C45 directory:
# ['7C42.pdb', '7C45.pdb', '7C42_mod.pdb', '7C45_mod.pdb', '7C45_7C42.pdb']
#
# (174) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7DOL
# Total 5 PDB files in 7DOL directory.
# All files in 7DOL directory:
# ['7DOL_7DCY.pdb', '7DOL.pdb', '7DOL_mod.pdb', '7DCY_mod.pdb', '7DCY.pdb']
#
# (175) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7K5L
# Total 5 PDB files in 7K5L directory.
# All files in 7K5L directory:
# ['4LDM.pdb', '7K5L_4LDM.pdb', '4LDM_mod.pdb', '7K5L.pdb', '7K5L_mod.pdb']
#
# (176) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7EIU
# Total 5 PDB files in 7EIU directory.
# All files in 7EIU directory:
# ['7EIO.pdb', '7EIU.pdb', '7EIU_7EIO.pdb', '7EIO_mod.pdb', '7EIU_mod.pdb']
#
# (177) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7KL3
# Total 5 PDB files in 7KL3 directory.
# All files in 7KL3 directory:
# ['7KL3_5CZN.pdb', '5CZN.pdb', '5CZN_mod.pdb', '7KL3_mod.pdb', '7KL3.pdb']
#
# (178) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7L6T
# Total 5 PDB files in 7L6T directory.
# All files in 7L6T directory:
# ['7L6T_7C2I.pdb', '7L6T_mod.pdb', '7C2I.pdb', '7C2I_mod.pdb', '7L6T.pdb']
#
# (179) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7V4G
# Total 5 PDB files in 7V4G directory.
# All files in 7V4G directory:
# ['7V4G_4O61.pdb', '7V4G_mod.pdb', '7V4G.pdb', '4O61.pdb', '4O61_mod.pdb']
#
# (180) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7VSJ
# Total 5 PDB files in 7VSJ directory.
# All files in 7VSJ directory:
# ['7VSJ.pdb', '7VSJ_6FQ1.pdb', '7VSJ_mod.pdb', '6FQ1.pdb', '6FQ1_mod.pdb']
#
# (181) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7VKI
# Total 5 PDB files in 7VKI directory.
# All files in 7VKI directory:
# ['2DHA_mod.pdb', '7VKI.pdb', '7VKI_mod.pdb', '2DHA.pdb', '7VKI_2DHA.pdb']
#
# (182) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7VKL
# Total 5 PDB files in 7VKL directory.
# All files in 7VKL directory:
# ['6GQE.pdb', '6GQE_mod.pdb', '7VKL.pdb', '7VKL_mod.pdb', '7VKL_6GQE.pdb']
#
# (183) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7Y7Q
# Total 5 PDB files in 7Y7Q directory.
# All files in 7Y7Q directory:
# ['2J7N.pdb', '2J7N_mod.pdb', '7Y7Q_2J7N.pdb', '7Y7Q.pdb', '7Y7Q_mod.pdb']
#
# (184) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8DZK
# Total 5 PDB files in 8DZK directory.
# All files in 8DZK directory:
# ['8DZK_5K71.pdb', '8DZK.pdb', '5K71.pdb', '8DZK_mod.pdb', '5K71_mod.pdb']
#
# (185) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8EDJ
# Total 5 PDB files in 8EDJ directory.
# All files in 8EDJ directory:
# ['8EDJ_6P3X.pdb', '6P3X.pdb', '8EDJ.pdb', '8EDJ_mod.pdb', '6P3X_mod.pdb']
#
# (186) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8AXF
# Total 5 PDB files in 8AXF directory.
# All files in 8AXF directory:
# ['8AXF_mod.pdb', '8AX4_mod.pdb', '8AXF.pdb', '8AXF_8AX4.pdb', '8AX4.pdb']
#
# (187) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8TG4
# Total 5 PDB files in 8TG4 directory.
# All files in 8TG4 directory:
# ['8TG3_mod.pdb', '8TG4_mod.pdb', '8TG3.pdb', '8TG4.pdb', '8TG4_8TG3.pdb']
#
# (188) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZM5
# Total 5 PDB files in 2ZM5 directory.
# All files in 2ZM5 directory:
# ['2ZM5_3L0U.pdb', '2ZM5_mod.pdb', '3L0U_mod.pdb', '3L0U.pdb', '2ZM5.pdb']
#
# (189) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3ZJT
# Total 5 PDB files in 3ZJT directory.
# All files in 3ZJT directory:
# ['2NQP_mod.pdb', '3ZJT_2NQP.pdb', '3ZJT.pdb', '2NQP.pdb', '3ZJT_mod.pdb']
#
# (190) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6AAX
# Total 5 PDB files in 6AAX directory.
# All files in 6AAX directory:
# ['6AAS_mod.pdb', '6AAX_6AAS.pdb', '6AAX.pdb', '6AAX_mod.pdb', '6AAS.pdb']
#
# (191) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1HQ1
# Total 5 PDB files in 1HQ1 directory.
# All files in 1HQ1 directory:
# ['1HQ1_mod.pdb', '1DUH_mod.pdb', '1HQ1.pdb', '1HQ1_1DUH.pdb', '1DUH.pdb']
#
# (192) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1JID
# Total 5 PDB files in 1JID directory.
# All files in 1JID directory:
# ['1JID_1D4R.pdb', '1D4R.pdb', '1JID_mod.pdb', '1JID.pdb', '1D4R_mod.pdb']
#
# (193) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2PJP
# Total 5 PDB files in 2PJP directory.
# All files in 2PJP directory:
# ['1MFK.pdb', '2PJP_mod.pdb', '1MFK_mod.pdb', '2PJP.pdb', '2PJP_1MFK.pdb']
#
# (194) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3BT7
# Total 5 PDB files in 3BT7 directory.
# All files in 3BT7 directory:
# ['3BT7_mod.pdb', '3BT7_1EVV.pdb', '3BT7.pdb', '1EVV.pdb', '1EVV_mod.pdb']
#
# (195) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6HTU
# Total 5 PDB files in 6HTU directory.
# All files in 6HTU directory:
# ['6HU6.pdb', '6HTU.pdb', '6HTU_6HU6.pdb', '6HU6_mod.pdb', '6HTU_mod.pdb']
#
# (196) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1LNG
# Total 5 PDB files in 1LNG directory.
# All files in 1LNG directory:
# ['1LNG_1Z43.pdb', '1Z43.pdb', '1LNG_mod.pdb', '1Z43_mod.pdb', '1LNG.pdb']
#
# (197) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2I82
# Total 5 PDB files in 2I82 directory.
# All files in 2I82 directory:
# ['2I82_3L0U.pdb', '2I82.pdb', '3L0U_mod.pdb', '3L0U.pdb', '2I82_mod.pdb']

# %%
print(f"Number of unique PDB ID in each structural class:\n{prdbv3_read_json['Structural_class'].value_counts()}\n")
# Out:
# Number of unique PDB ID in each structural class:
# Structural_class
# D    86
# C    62
# A    40
# B     9
# Name: count, dtype: int64

# %%
# Read PRDBv3 data directory and its contents based on the different structural classes
def get_PRDBv3_info_by_class(path, df_to_parse, class_name):
    print(f"INFO PRDBv3:\nTotal {len(df_to_parse[df_to_parse['Structural_class'] == class_name]['C_PDB'].values)} directories in clas {class_name}: \n")
    # Iterate through each directory in the PRDBv3 dataset directory
    count_dir = 1
    for pdbdir in df_to_parse[df_to_parse['Structural_class'] == class_name]['C_PDB'].values:
        try:
            print(f'({count_dir}) Directory path:{os.path.join(path, pdbdir)}')
            print(f'Total {len(os.listdir(os.path.join(path, pdbdir)))} PDB files in {pdbdir} directory.')
            print(f'All files in {pdbdir} directory:\n{os.listdir(os.path.join(path, pdbdir))}\n')
            count_dir += 1
            # Catch exception for directories not found
        except:
            print(f'Directory not found: {os.path.join(path, pdbdir)}\n')
    
# Read directories, files and its contents in PRDBv3 dataset directory based on structural class
get_PRDBv3_info_by_class(PRDBv3_dir, prdbv3_read_json, 'A')
# Out:
# INFO PRDBv3:
# Total 40 directories in clas A:
#
# (1) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ASY
# Total 8 PDB files in 1ASY directory.
# All files in 1ASY directory:
# ['2TRA.pdb', '1EOV.pdb', '1ASY_1EOV.pdb', '2TRA_mod.pdb', '1ASY_mod.pdb', '1ASY_2TRA.pdb', '1ASY.pdb', '1EOV_mod.pdb']
#
# (2) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1B23
# Total 8 PDB files in 1B23 directory.
# All files in 1B23 directory:
# ['1TUI_mod.pdb', '1B23.pdb', '1TUI.pdb', '1U0B.pdb', '1B23_mod.pdb', '1U0B_mod.pdb', '1B23_1TUI.pdb', '1B23_1U0B.pdb']
#
# (3) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1C0A
# Total 8 PDB files in 1C0A directory.
# All files in 1C0A directory:
# ['1C0A_1EQR.pdb', '1C0A.pdb', '1EQR_mod.pdb', '1C0A_1EFW.pdb', '1EFW.pdb', '1EFW_mod.pdb', '1C0A_mod.pdb', '1EQR.pdb']
#
# (4) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1QTQ
# Total 8 PDB files in 1QTQ directory.
# All files in 1QTQ directory:
# ['1QTQ_mod.pdb', '1NYL.pdb', '1QTQ.pdb', '1QTQ_3KNH.pdb', '3KNH_mod.pdb', '3KNH.pdb', '1NYL_mod.pdb', '1QTQ_1NYL.pdb']
#
# (5) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BTE
# Total 8 PDB files in 2BTE directory.
# All files in 2BTE directory:
# ['2NQP_mod.pdb', '2BTE_1OBC.pdb', '2NQP.pdb', '1OBC.pdb', '1OBC_mod.pdb', '2BTE.pdb', '2BTE_2NQP.pdb', '2BTE_mod.pdb']
#
# (6) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2DRB
# Total 8 PDB files in 2DRB directory.
# All files in 2DRB directory:
# ['1UET.pdb', '2DRB.pdb', '3Q1Q_mod.pdb', '3Q1Q.pdb', '2DRB_1UET.pdb', '2DRB_3Q1Q.pdb', '2DRB_mod.pdb', '1UET_mod.pdb']
#
# (7) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2FMT
# Total 8 PDB files in 2FMT directory.
# All files in 2FMT directory:
# ['1FMT.pdb', '3CW6.pdb', '2FMT_3CW6.pdb', '2FMT_1FMT.pdb', '2FMT_mod.pdb', '2FMT.pdb', '1FMT_mod.pdb', '3CW6_mod.pdb']
#
# (8) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZZM
# Total 8 PDB files in 2ZZM directory.
# All files in 2ZZM directory:
# ['2ZZM_mod.pdb', '2YX1.pdb', '2YX1_mod.pdb', '1WZ2.pdb', '2ZZM_1WZ2.pdb', '2ZZM.pdb', '2ZZM_2YX1.pdb', '1WZ2_mod.pdb']
#
# (9) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3HL2
# Total 8 PDB files in 3HL2 directory.
# All files in 3HL2 directory:
# ['3RG5_mod.pdb', '3HL2_mod.pdb', '3RG5.pdb', '3BC8_mod.pdb', '3HL2_3RG5.pdb', '3HL2.pdb', '3HL2_3BC8.pdb', '3BC8.pdb']
#
# (10) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3VJR
# Total 8 PDB files in 3VJR directory.
# All files in 3VJR directory:
# ['2PTH_mod.pdb', '1NJM_mod.pdb', '3VJR_mod.pdb', '3VJR_1NJM.pdb', '1NJM.pdb', '3VJR_2PTH.pdb', '2PTH.pdb', '3VJR.pdb']
#
# (11) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5X6B
# Total 8 PDB files in 5X6B directory.
# All files in 5X6B directory:
# ['5X6B.pdb', '2ZZN_mod.pdb', '5X6B_mod.pdb', '2ZZN.pdb', '5X6B_2ZZN.pdb', '5X6B_3WKR.pdb', '3WKR.pdb', '3WKR_mod.pdb']
#
# (12) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6LVR
# Total 8 PDB files in 6LVR directory.
# All files in 6LVR directory:
# ['4G24_mod.pdb', '6LVR.pdb', '1I9V_mod.pdb', '4G24.pdb', '1I9V.pdb', '6LVR_mod.pdb', '6LVR_4G24.pdb', '6LVR_1I9V.pdb']
#
# (13) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7YSE
# Total 8 PDB files in 7YSE directory.
# All files in 7YSE directory:
# ['7EIV.pdb', '7YSE_7EIV.pdb', '7YSE.pdb', '7EIV_mod.pdb', '7F36_mod.pdb', '7YSE_mod.pdb', '7F36.pdb', '7YSE_7F36.pdb']
#
# (14) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1F7U
# Total 5 PDB files in 1F7U directory.
# All files in 1F7U directory:
# ['1F7U_1BS2.pdb', '1F7U.pdb', '1BS2.pdb', '1F7U_mod.pdb', '1BS2_mod.pdb']
#
# (15) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1H3E
# Total 5 PDB files in 1H3E directory.
# All files in 1H3E directory:
# ['1H3F_mod.pdb', '1H3E_mod.pdb', '1H3E.pdb', '1H3E_1H3F.pdb', '1H3F.pdb']
#
# (16) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1H4S
# Total 5 PDB files in 1H4S directory.
# All files in 1H4S directory:
# ['1H4S_mod.pdb', '1H4S.pdb', '1H4S_1HC7.pdb', '1HC7_mod.pdb', '1HC7.pdb']
#
# (17) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1J1U
# Total 5 PDB files in 1J1U directory.
# All files in 1J1U directory:
# ['1J1U_1U7D.pdb', '1U7D.pdb', '1U7D_mod.pdb', '1J1U.pdb', '1J1U_mod.pdb']
#
# (18) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1N78
# Total 5 PDB files in 1N78 directory.
# All files in 1N78 directory:
# ['1N78.pdb', '1J09_mod.pdb', '1N78_mod.pdb', '1N78_1J09.pdb', '1J09.pdb']
#
# (19) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1QF6
# Total 5 PDB files in 1QF6 directory.
# All files in 1QF6 directory:
# ['1QF6_mod.pdb', '1EVL_mod.pdb', '1QF6.pdb', '1EVL.pdb', '1QF6_1EVL.pdb']
#
# (20) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1SER
# Total 5 PDB files in 1SER directory.
# All files in 1SER directory:
# ['1SER_1SES.pdb', '1SER.pdb', '1SES_mod.pdb', '1SER_mod.pdb', '1SES.pdb']
#
# (21) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1U0B
# Total 5 PDB files in 1U0B directory.
# All files in 1U0B directory:
# ['1U0B_1LI5.pdb', '1LI5_mod.pdb', '1LI5.pdb', '1U0B.pdb', '1U0B_mod.pdb']
#
# (22) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1VFG
# Total 5 PDB files in 1VFG directory.
# All files in 1VFG directory:
# ['4WBY_mod.pdb', '4WBY.pdb', '1VFG_4WBY.pdb', '1VFG_mod.pdb', '1VFG.pdb']
#
# (23) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2AZX
# Total 5 PDB files in 2AZX directory.
# All files in 2AZX directory:
# ['2AZX_1R6U.pdb', '2AZX_mod.pdb', '1R6U_mod.pdb', '2AZX.pdb', '1R6U.pdb']
#
# (24) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2FK6
# Total 5 PDB files in 2FK6 directory.
# All files in 2FK6 directory:
# ['1Y44_mod.pdb', '1Y44.pdb', '2FK6_mod.pdb', '2FK6.pdb', '2FK6_1Y44.pdb']
#
# (25) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3ADB
# Total 5 PDB files in 3ADB directory.
# All files in 3ADB directory:
# ['3ADB.pdb', '3A4M_mod.pdb', '3A4M.pdb', '3ADB_3A4M.pdb', '3ADB_mod.pdb']
#
# (26) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3AMT
# Total 5 PDB files in 3AMT directory.
# All files in 3AMT directory:
# ['3AU7.pdb', '3AMT_3AU7.pdb', '3AU7_mod.pdb', '3AMT.pdb', '3AMT_mod.pdb']
#
# (27) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4YCP
# Total 5 PDB files in 4YCP directory.
# All files in 4YCP directory:
# ['4YCP_mod.pdb', '4YCP.pdb', '4BFA.pdb', '4YCP_4BFA.pdb', '4BFA_mod.pdb']
#
# (28) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4YVJ
# Total 5 PDB files in 4YVJ directory.
# All files in 4YVJ directory:
# ['4YVJ_mod.pdb', '3AXZ_mod.pdb', '4YVJ_3AXZ.pdb', '3AXZ.pdb', '4YVJ.pdb']
#
# (29) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5HR7
# Total 5 PDB files in 5HR7 directory.
# All files in 5HR7 directory:
# ['5HR7.pdb', '5HR7_mod.pdb', '3RFA_mod.pdb', '3RFA.pdb', '5HR7_3RFA.pdb']
#
# (30) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5B63
# Total 5 PDB files in 5B63 directory.
# All files in 5B63 directory:
# ['5B63_5YYM.pdb', '5YYM.pdb', '5B63_mod.pdb', '5YYM_mod.pdb', '5B63.pdb']
#
# (31) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5T8Y
# Total 5 PDB files in 5T8Y directory.
# All files in 5T8Y directory:
# ['5D08_mod.pdb', '5T8Y_5D08.pdb', '5T8Y.pdb', '5D08.pdb', '5T8Y_mod.pdb']
#
# (32) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WT1
# Total 5 PDB files in 5WT1 directory.
# All files in 5WT1 directory:
# ['5WT1.pdb', '5WT1_5HJI.pdb', '5HJI.pdb', '5WT1_mod.pdb', '5HJI_mod.pdb']
#
# (33) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZW4
# Total 5 PDB files in 5ZW4 directory.
# All files in 5ZW4 directory:
# ['5ZW3_mod.pdb', '5ZW4_mod.pdb', '5ZW4_5ZW3.pdb', '5ZW3.pdb', '5ZW4.pdb']
#
# (34) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7E8O
# Total 5 PDB files in 7E8O directory.
# All files in 7E8O directory:
# ['7E8O_7E8K.pdb', '7E8K.pdb', '7E8O.pdb', '7E8O_mod.pdb', '7E8K_mod.pdb']
#
# (35) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7K98
# Total 5 PDB files in 7K98 directory.
# All files in 7K98 directory:
# ['7DAW_mod.pdb', '7K98_mod.pdb', '7K98_7DAW.pdb', '7DAW.pdb', '7K98.pdb']
#
# (36) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7MJW
# Total 5 PDB files in 7MJW directory.
# All files in 7MJW directory:
# ['7MJW_mod.pdb', '7MJZ_mod.pdb', '7MJZ.pdb', '7MJW_7MJZ.pdb', '7MJW.pdb']
#
# (37) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8H1B
# Total 5 PDB files in 8H1B directory.
# All files in 8H1B directory:
# ['8H1B_mod.pdb', '8H1A.pdb', '8H1A_mod.pdb', '8H1B_8H1A.pdb', '8H1B.pdb']
#
# (38) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8JOZ
# Total 5 PDB files in 8JOZ directory.
# All files in 8JOZ directory:
# ['8JOZ_4HTF.pdb', '4HTF_mod.pdb', '4HTF.pdb', '8JOZ.pdb', '8JOZ_mod.pdb']
#
# (39) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZM5
# Total 5 PDB files in 2ZM5 directory.
# All files in 2ZM5 directory:
# ['2ZM5_3L0U.pdb', '2ZM5_mod.pdb', '3L0U_mod.pdb', '3L0U.pdb', '2ZM5.pdb']
#
# (40) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3ZJT
# Total 5 PDB files in 3ZJT directory.
# All files in 3ZJT directory:
# ['2NQP_mod.pdb', '3ZJT_2NQP.pdb', '3ZJT.pdb', '2NQP.pdb', '3ZJT_mod.pdb']

# %%
print(f"Number of unique PDB ID in each flexible class:\n{prdbv3_read_json['Flexible_class'].value_counts()}\n")
# Out:
# Number of unique PDB ID in each flexible class:
# Flexible_class
# R    117
# S     41
# F     29
# Name: count, dtype: int64

# %%
# Read PRDBv3 data directory and its contents based on the different flexible class
def get_PRDBv3_info_by_flexible_class(path, df_to_parse, flex_class):
    print(f"INFO PRDBv3:\nTotal {len(df_to_parse[df_to_parse['Flexible_class'] == flex_class]['C_PDB'].values)} directories in flexible class {flex_class}: \n")
    # Iterate through each directory in the PRDBv3 dataset directory
    count_dir = 1
    for pdbdir in df_to_parse[df_to_parse['Flexible_class'] == flex_class]['C_PDB'].values:
        try:
            print(f'({count_dir}) Directory path:{os.path.join(path, pdbdir)}')
            print(f'Total {len(os.listdir(os.path.join(path, pdbdir)))} PDB files in {pdbdir} directory.')
            print(f'All files in {pdbdir} directory:\n{os.listdir(os.path.join(path, pdbdir))}\n')
            count_dir += 1
            # Catch exception for directories not found
        except:
            print(f'Directory not found: {os.path.join(path, pdbdir)}\n')
# Read directories, files and its contents in PRDBv3 dataset directory based on flexible class
get_PRDBv3_info_by_flexible_class(PRDBv3_dir, prdbv3_read_json, 'R')
# Out:
# INFO PRDBv3:
# Total 117 directories in flexible class R:
#
# (1) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ASY
# Total 8 PDB files in 1ASY directory.
# All files in 1ASY directory:
# ['2TRA.pdb', '1EOV.pdb', '1ASY_1EOV.pdb', '2TRA_mod.pdb', '1ASY_mod.pdb', '1ASY_2TRA.pdb', '1ASY.pdb', '1EOV_mod.pdb']
#
# (2) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BTE
# Total 8 PDB files in 2BTE directory.
# All files in 2BTE directory:
# ['2NQP_mod.pdb', '2BTE_1OBC.pdb', '2NQP.pdb', '1OBC.pdb', '1OBC_mod.pdb', '2BTE.pdb', '2BTE_2NQP.pdb', '2BTE_mod.pdb']
#
# (3) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2FMT
# Total 8 PDB files in 2FMT directory.
# All files in 2FMT directory:
# ['1FMT.pdb', '3CW6.pdb', '2FMT_3CW6.pdb', '2FMT_1FMT.pdb', '2FMT_mod.pdb', '2FMT.pdb', '1FMT_mod.pdb', '3CW6_mod.pdb']
#
# (4) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3HL2
# Total 8 PDB files in 3HL2 directory.
# All files in 3HL2 directory:
# ['3RG5_mod.pdb', '3HL2_mod.pdb', '3RG5.pdb', '3BC8_mod.pdb', '3HL2_3RG5.pdb', '3HL2.pdb', '3HL2_3BC8.pdb', '3BC8.pdb']
#
# (5) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3VJR
# Total 8 PDB files in 3VJR directory.
# All files in 3VJR directory:
# ['2PTH_mod.pdb', '1NJM_mod.pdb', '3VJR_mod.pdb', '3VJR_1NJM.pdb', '1NJM.pdb', '3VJR_2PTH.pdb', '2PTH.pdb', '3VJR.pdb']
#
# (6) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5X6B
# Total 8 PDB files in 5X6B directory.
# All files in 5X6B directory:
# ['5X6B.pdb', '2ZZN_mod.pdb', '5X6B_mod.pdb', '2ZZN.pdb', '5X6B_2ZZN.pdb', '5X6B_3WKR.pdb', '3WKR.pdb', '3WKR_mod.pdb']
#
# (7) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3IEV
# Total 8 PDB files in 3IEV directory.
# All files in 3IEV directory:
# ['3IEV.pdb', '1SDR_mod.pdb', '3IEV_mod.pdb', '1SDR.pdb', '7C1O_mod.pdb', '3IEV_7C1O.pdb', '7C1O.pdb', '3IEV_1SDR.pdb']
#
# (8) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1JBS
# Total 8 PDB files in 1JBS directory.
# All files in 1JBS directory:
# ['1Q9A.pdb', '1Q9A_mod.pdb', '1JBS_1Q9A.pdb', '1JBS_1AQZ.pdb', '1AQZ.pdb', '1JBS.pdb', '1AQZ_mod.pdb', '1JBS_mod.pdb']
#
# (9) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WSU
# Total 8 PDB files in 1WSU directory.
# All files in 1WSU directory:
# ['1WSU_mod.pdb', '1WSU_2RLU.pdb', '1LVA_mod.pdb', '2RLU_mod.pdb', '1WSU.pdb', '1LVA.pdb', '1WSU_1LVA.pdb', '2RLU.pdb']
#
# (10) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ZBH
# Total 8 PDB files in 1ZBH directory.
# All files in 1ZBH directory:
# ['1ZBH.pdb', '1JU7.pdb', '1ZBH_1ZBU.pdb', '1JU7_mod.pdb', '1ZBH_mod.pdb', '1ZBH_1JU7.pdb', '1ZBU_mod.pdb', '1ZBU.pdb']
#
# (11) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BH2
# Total 8 PDB files in 2BH2 directory.
# All files in 2BH2 directory:
# ['2BH2_1UWV.pdb', '1UWV.pdb', '1UWV_mod.pdb', '2BH2_mod.pdb', '1JZX.pdb', '2BH2.pdb', '1JZX_mod.pdb', '2BH2_1JZX.pdb']
#
# (12) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1H4S
# Total 5 PDB files in 1H4S directory.
# All files in 1H4S directory:
# ['1H4S_mod.pdb', '1H4S.pdb', '1H4S_1HC7.pdb', '1HC7_mod.pdb', '1HC7.pdb']
#
# (13) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1J1U
# Total 5 PDB files in 1J1U directory.
# All files in 1J1U directory:
# ['1J1U_1U7D.pdb', '1U7D.pdb', '1U7D_mod.pdb', '1J1U.pdb', '1J1U_mod.pdb']
#
# (14) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1N78
# Total 5 PDB files in 1N78 directory.
# All files in 1N78 directory:
# ['1N78.pdb', '1J09_mod.pdb', '1N78_mod.pdb', '1N78_1J09.pdb', '1J09.pdb']
#
# (15) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1QF6
# Total 5 PDB files in 1QF6 directory.
# All files in 1QF6 directory:
# ['1QF6_mod.pdb', '1EVL_mod.pdb', '1QF6.pdb', '1EVL.pdb', '1QF6_1EVL.pdb']
#
# (16) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1U0B
# Total 5 PDB files in 1U0B directory.
# All files in 1U0B directory:
# ['1U0B_1LI5.pdb', '1LI5_mod.pdb', '1LI5.pdb', '1U0B.pdb', '1U0B_mod.pdb']
#
# (17) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1VFG
# Total 5 PDB files in 1VFG directory.
# All files in 1VFG directory:
# ['4WBY_mod.pdb', '4WBY.pdb', '1VFG_4WBY.pdb', '1VFG_mod.pdb', '1VFG.pdb']
#
# (18) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2AZX
# Total 5 PDB files in 2AZX directory.
# All files in 2AZX directory:
# ['2AZX_1R6U.pdb', '2AZX_mod.pdb', '1R6U_mod.pdb', '2AZX.pdb', '1R6U.pdb']
#
# (19) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2FK6
# Total 5 PDB files in 2FK6 directory.
# All files in 2FK6 directory:
# ['1Y44_mod.pdb', '1Y44.pdb', '2FK6_mod.pdb', '2FK6.pdb', '2FK6_1Y44.pdb']
#
# (20) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3AMT
# Total 5 PDB files in 3AMT directory.
# All files in 3AMT directory:
# ['3AU7.pdb', '3AMT_3AU7.pdb', '3AU7_mod.pdb', '3AMT.pdb', '3AMT_mod.pdb']
#
# (21) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4YVJ
# Total 5 PDB files in 4YVJ directory.
# All files in 4YVJ directory:
# ['4YVJ_mod.pdb', '3AXZ_mod.pdb', '4YVJ_3AXZ.pdb', '3AXZ.pdb', '4YVJ.pdb']
#
# (22) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5HR7
# Total 5 PDB files in 5HR7 directory.
# All files in 5HR7 directory:
# ['5HR7.pdb', '5HR7_mod.pdb', '3RFA_mod.pdb', '3RFA.pdb', '5HR7_3RFA.pdb']
#
# (23) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5T8Y
# Total 5 PDB files in 5T8Y directory.
# All files in 5T8Y directory:
# ['5D08_mod.pdb', '5T8Y_5D08.pdb', '5T8Y.pdb', '5D08.pdb', '5T8Y_mod.pdb']
#
# (24) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZW4
# Total 5 PDB files in 5ZW4 directory.
# All files in 5ZW4 directory:
# ['5ZW3_mod.pdb', '5ZW4_mod.pdb', '5ZW4_5ZW3.pdb', '5ZW3.pdb', '5ZW4.pdb']
#
# (25) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7E8O
# Total 5 PDB files in 7E8O directory.
# All files in 7E8O directory:
# ['7E8O_7E8K.pdb', '7E8K.pdb', '7E8O.pdb', '7E8O_mod.pdb', '7E8K_mod.pdb']
#
# (26) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8JOZ
# Total 5 PDB files in 8JOZ directory.
# All files in 8JOZ directory:
# ['8JOZ_4HTF.pdb', '4HTF_mod.pdb', '4HTF.pdb', '8JOZ.pdb', '8JOZ_mod.pdb']
#
# (27) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1G1X
# Total 5 PDB files in 1G1X directory.
# All files in 1G1X directory:
# ['1G1X_mod.pdb', '1G1X.pdb', '1CQM.pdb', '1CQM_mod.pdb', '1G1X_1CQM.pdb']
#
# (28) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1SDS
# Total 5 PDB files in 1SDS directory.
# All files in 1SDS directory:
# ['1SDS_1XBI.pdb', '1XBI.pdb', '1SDS.pdb', '1SDS_mod.pdb', '1XBI_mod.pdb']
#
# (29) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1N35
# Total 5 PDB files in 1N35 directory.
# All files in 1N35 directory:
# ['1MUK.pdb', '1N35_1MUK.pdb', '1MUK_mod.pdb', '1N35.pdb', '1N35_mod.pdb']
#
# (30) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WNE
# Total 5 PDB files in 1WNE directory.
# All files in 1WNE directory:
# ['1WNE_mod.pdb', '1U09_mod.pdb', '1U09.pdb', '1WNE.pdb', '1WNE_1U09.pdb']
#
# (31) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1YVP
# Total 5 PDB files in 1YVP directory.
# All files in 1YVP directory:
# ['1YVP_1YVR.pdb', '1YVR.pdb', '1YVP_mod.pdb', '1YVR_mod.pdb', '1YVP.pdb']
#
# (32) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ZBI
# Total 5 PDB files in 1ZBI directory.
# All files in 1ZBI directory:
# ['1ZBI_mod.pdb', '1ZBF.pdb', '1ZBI.pdb', '1ZBF_mod.pdb', '1ZBI_1ZBF.pdb']
#
# (33) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2AZ0
# Total 5 PDB files in 2AZ0 directory.
# All files in 2AZ0 directory:
# ['2B9Z_mod.pdb', '2B9Z.pdb', '2AZ0_2B9Z.pdb', '2AZ0_mod.pdb', '2AZ0.pdb']
#
# (34) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BGG
# Total 5 PDB files in 2BGG directory.
# All files in 2BGG directory:
# ['1W9H_mod.pdb', '2BGG_1W9H.pdb', '1W9H.pdb', '2BGG_mod.pdb', '2BGG.pdb']
#
# (35) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2EZ6
# Total 5 PDB files in 2EZ6 directory.
# All files in 2EZ6 directory:
# ['1JFZ_mod.pdb', '2EZ6.pdb', '1JFZ.pdb', '2EZ6_mod.pdb', '2EZ6_1JFZ.pdb']
#
# (36) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2GJW
# Total 5 PDB files in 2GJW directory.
# All files in 2GJW directory:
# ['1R0V_mod.pdb', '2GJW.pdb', '1R0V.pdb', '2GJW_1R0V.pdb', '2GJW_mod.pdb']
#
# (37) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2GXB
# Total 5 PDB files in 2GXB directory.
# All files in 2GXB directory:
# ['2GXB.pdb', '1QGP.pdb', '2GXB_1QGP.pdb', '2GXB_mod.pdb', '1QGP_mod.pdb']
#
# (38) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2QUX
# Total 5 PDB files in 2QUX directory.
# All files in 2QUX directory:
# ['2QUX_mod.pdb', '2QUD_mod.pdb', '2QUX_2QUD.pdb', '2QUX.pdb', '2QUD.pdb']
#
# (39) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZKO
# Total 5 PDB files in 2ZKO directory.
# All files in 2ZKO directory:
# ['2Z0A.pdb', '2ZKO_mod.pdb', '2Z0A_mod.pdb', '2ZKO_2Z0A.pdb', '2ZKO.pdb']
#
# (40) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3A6P
# Total 5 PDB files in 3A6P directory.
# All files in 3A6P directory:
# ['3A6P.pdb', '3A6P_mod.pdb', '3A6P_5YU6.pdb', '5YU6.pdb', '5YU6_mod.pdb']
#
# (41) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3DD2
# Total 5 PDB files in 3DD2 directory.
# All files in 3DD2 directory:
# ['3DD2_mod.pdb', '1JOU.pdb', '1JOU_mod.pdb', '3DD2.pdb', '3DD2_1JOU.pdb']
#
# (42) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3EQT
# Total 5 PDB files in 3EQT directory.
# All files in 3EQT directory:
# ['2W4R_mod.pdb', '2W4R.pdb', '3EQT_2W4R.pdb', '3EQT_mod.pdb', '3EQT.pdb']
#
# (43) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3FTE
# Total 5 PDB files in 3FTE directory.
# All files in 3FTE directory:
# ['3FTE_3FTD.pdb', '3FTE_mod.pdb', '3FTD.pdb', '3FTE.pdb', '3FTD_mod.pdb']
#
# (44) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3KS8
# Total 5 PDB files in 3KS8 directory.
# All files in 3KS8 directory:
# ['3KS8.pdb', '3KS4_mod.pdb', '3KS4.pdb', '3KS8_3KS4.pdb', '3KS8_mod.pdb']
#
# (45) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3MOJ
# Total 5 PDB files in 3MOJ directory.
# All files in 3MOJ directory:
# ['3MOJ.pdb', '3MOJ_2G0C.pdb', '2G0C.pdb', '2G0C_mod.pdb', '3MOJ_mod.pdb']
#
# (46) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3OL6
# Total 5 PDB files in 3OL6 directory.
# All files in 3OL6 directory:
# ['3OL6.pdb', '3OL6_mod.pdb', '1RA6_mod.pdb', '3OL6_1RA6.pdb', '1RA6.pdb']
#
# (47) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3ZC0
# Total 5 PDB files in 3ZC0 directory.
# All files in 3ZC0 directory:
# ['3ZC0_mod.pdb', '3ZC1.pdb', '3ZC0.pdb', '3ZC0_3ZC1.pdb', '3ZC1_mod.pdb']
#
# (48) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4ERD
# Total 5 PDB files in 4ERD directory.
# All files in 4ERD directory:
# ['4EYT.pdb', '4EYT_mod.pdb', '4ERD.pdb', '4ERD_4EYT.pdb', '4ERD_mod.pdb']
#
# (49) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4FVU
# Total 5 PDB files in 4FVU directory.
# All files in 4FVU directory:
# ['4FVU_mod.pdb', '4FVU_3Q7C.pdb', '4FVU.pdb', '3Q7C_mod.pdb', '3Q7C.pdb']
#
# (50) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4ILL
# Total 5 PDB files in 4ILL directory.
# All files in 4ILL directory:
# ['4ILL_mod.pdb', '4ILL.pdb', '4ILL_4ILR.pdb', '4ILR.pdb', '4ILR_mod.pdb']
#
# (51) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5F5H
# Total 5 PDB files in 5F5H directory.
# All files in 5F5H directory:
# ['5F5H.pdb', '5F5H_mod.pdb', '4QI0_mod.pdb', '5F5H_4QI0.pdb', '4QI0.pdb']
#
# (52) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZQ8
# Total 5 PDB files in 5ZQ8 directory.
# All files in 5ZQ8 directory:
# ['5ZQ8_mod.pdb', '5ZQ8_5XJ1.pdb', '5XJ1.pdb', '5ZQ8.pdb', '5XJ1_mod.pdb']
#
# (53) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6DCB
# Total 5 PDB files in 6DCB directory.
# All files in 6DCB directory:
# ['6DCB_mod.pdb', '5UNA.pdb', '6DCB_5UNA.pdb', '5UNA_mod.pdb', '6DCB.pdb']
#
# (54) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6PZQ
# Total 5 PDB files in 6PZQ directory.
# All files in 6PZQ directory:
# ['6G0Y.pdb', '6G0Y_mod.pdb', '6PZQ_6G0Y.pdb', '6PZQ.pdb', '6PZQ_mod.pdb']
#
# (55) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6RTI
# Total 5 PDB files in 6RTI directory.
# All files in 6RTI directory:
# ['2C6C_mod.pdb', '6RTI.pdb', '6RTI_2C6C.pdb', '6RTI_mod.pdb', '2C6C.pdb']
#
# (56) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7KKV
# Total 5 PDB files in 7KKV directory.
# All files in 7KKV directory:
# ['7K9B.pdb', '7K9B_mod.pdb', '7KKV_mod.pdb', '7KKV_7K9B.pdb', '7KKV.pdb']
#
# (57) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7OM6
# Total 5 PDB files in 7OM6 directory.
# All files in 7OM6 directory:
# ['7OM6_mod.pdb', '7OM6_7OM2.pdb', '7OM2_mod.pdb', '7OM6.pdb', '7OM2.pdb']
#
# (58) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7ZLQ
# Total 5 PDB files in 7ZLQ directory.
# All files in 7ZLQ directory:
# ['7ZLQ_mod.pdb', '2MDR.pdb', '2MDR_mod.pdb', '7ZLQ.pdb', '7ZLQ_2MDR.pdb']
#
# (59) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8AF0
# Total 5 PDB files in 8AF0 directory.
# All files in 8AF0 directory:
# ['8AF0_mod.pdb', '8AF0.pdb', '5M9T_mod.pdb', '8AF0_5M9T.pdb', '5M9T.pdb']
#
# (60) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1AV6
# Total 5 PDB files in 1AV6 directory.
# All files in 1AV6 directory:
# ['1AV6_mod.pdb', '1AV6.pdb', '1AV6_1B42.pdb', '1B42_mod.pdb', '1B42.pdb']
#
# (61) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1C9S
# Total 5 PDB files in 1C9S directory.
# All files in 1C9S directory:
# ['2EXT.pdb', '1C9S.pdb', '1C9S_2EXT.pdb', '2EXT_mod.pdb', '1C9S_mod.pdb']
#
# (62) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1G2E
# Total 5 PDB files in 1G2E directory.
# All files in 1G2E directory:
# ['1G2E_mod.pdb', '4EGL.pdb', '1G2E_4EGL.pdb', '1G2E.pdb', '4EGL_mod.pdb']
#
# (63) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1K8W
# Total 5 PDB files in 1K8W directory.
# All files in 1K8W directory:
# ['1R3F_mod.pdb', '1K8W_1R3F.pdb', '1K8W.pdb', '1K8W_mod.pdb', '1R3F.pdb']
#
# (64) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1KQ2
# Total 5 PDB files in 1KQ2 directory.
# All files in 1KQ2 directory:
# ['1KQ2.pdb', '1KQ1_mod.pdb', '1KQ1.pdb', '1KQ2_1KQ1.pdb', '1KQ2_mod.pdb']
#
# (65) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1M5O
# Total 5 PDB files in 1M5O directory.
# All files in 1M5O directory:
# ['1OIA.pdb', '1M5O_mod.pdb', '1OIA_mod.pdb', '1M5O_1OIA.pdb', '1M5O.pdb']
#
# (66) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1M8V
# Total 5 PDB files in 1M8V directory.
# All files in 1M8V directory:
# ['1M8V.pdb', '1M8V_mod.pdb', '1H64_mod.pdb', '1H64.pdb', '1M8V_1H64.pdb']
#
# (67) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1M8W
# Total 5 PDB files in 1M8W directory.
# All files in 1M8W directory:
# ['1M8Z_mod.pdb', '1M8W.pdb', '1M8Z.pdb', '1M8W_1M8Z.pdb', '1M8W_mod.pdb']
#
# (68) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1UVI
# Total 5 PDB files in 1UVI directory.
# All files in 1UVI directory:
# ['1HHS_mod.pdb', '1UVI.pdb', '1HHS.pdb', '1UVI_mod.pdb', '1UVI_1HHS.pdb']
#
# (69) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WPU
# Total 5 PDB files in 1WPU directory.
# All files in 1WPU directory:
# ['1WPU_mod.pdb', '1WPV.pdb', '1WPV_mod.pdb', '1WPU_1WPV.pdb', '1WPU.pdb']
#
# (70) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ASB
# Total 5 PDB files in 2ASB directory.
# All files in 2ASB directory:
# ['2ASB_1K0R.pdb', '1K0R.pdb', '1K0R_mod.pdb', '2ASB_mod.pdb', '2ASB.pdb']
#
# (71) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2GIC
# Total 5 PDB files in 2GIC directory.
# All files in 2GIC directory:
# ['2QVJ_mod.pdb', '2GIC_mod.pdb', '2GIC.pdb', '2QVJ.pdb', '2GIC_2QVJ.pdb']
#
# (72) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2IX1
# Total 5 PDB files in 2IX1 directory.
# All files in 2IX1 directory:
# ['2IX0.pdb', '2IX0_mod.pdb', '2IX1.pdb', '2IX1_2IX0.pdb', '2IX1_mod.pdb']
#
# (73) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2JEA
# Total 5 PDB files in 2JEA directory.
# All files in 2JEA directory:
# ['2JE6_mod.pdb', '2JEA_mod.pdb', '2JEA_2JE6.pdb', '2JEA.pdb', '2JE6.pdb']
#
# (74) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2PY9
# Total 5 PDB files in 2PY9 directory.
# All files in 2PY9 directory:
# ['2PY9_2JZX.pdb', '2PY9.pdb', '2PY9_mod.pdb', '2JZX_mod.pdb', '2JZX.pdb']
#
# (75) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2XNR
# Total 5 PDB files in 2XNR directory.
# All files in 2XNR directory:
# ['2XNR.pdb', '2XNR_2XNQ.pdb', '2XNR_mod.pdb', '2XNQ.pdb', '2XNQ_mod.pdb']
#
# (76) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3AEV
# Total 5 PDB files in 3AEV directory.
# All files in 3AEV directory:
# ['3AEV.pdb', '2E3U.pdb', '2E3U_mod.pdb', '3AEV_mod.pdb', '3AEV_2E3U.pdb']
#
# (77) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3BX2
# Total 5 PDB files in 3BX2 directory.
# All files in 3BX2 directory:
# ['3BX2_3BWT.pdb', '3BWT.pdb', '3BWT_mod.pdb', '3BX2.pdb', '3BX2_mod.pdb']
#
# (78) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3D2S
# Total 5 PDB files in 3D2S directory.
# All files in 3D2S directory:
# ['3D2Q_mod.pdb', '3D2S_mod.pdb', '3D2S_3D2Q.pdb', '3D2Q.pdb', '3D2S.pdb']
#
# (79) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3MDG
# Total 5 PDB files in 3MDG directory.
# All files in 3MDG directory:
# ['3MDG_3BAP.pdb', '3BAP.pdb', '3BAP_mod.pdb', '3MDG_mod.pdb', '3MDG.pdb']
#
# (80) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3O8C
# Total 5 PDB files in 3O8C directory.
# All files in 3O8C directory:
# ['3O8B_mod.pdb', '3O8C_3O8B.pdb', '3O8C.pdb', '3O8C_mod.pdb', '3O8B.pdb']
#
# (81) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3PF4
# Total 5 PDB files in 3PF4 directory.
# All files in 3PF4 directory:
# ['1CSP_mod.pdb', '3PF4_1CSP.pdb', '3PF4_mod.pdb', '3PF4.pdb', '1CSP.pdb']
#
# (82) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3QJJ
# Total 5 PDB files in 3QJJ directory.
# All files in 3QJJ directory:
# ['3QJJ.pdb', '3QJJ_3UFC.pdb', '3UFC.pdb', '3QJJ_mod.pdb', '3UFC_mod.pdb']
#
# (83) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3RC8
# Total 5 PDB files in 3RC8 directory.
# All files in 3RC8 directory:
# ['3RC8_3RC3.pdb', '3RC8.pdb', '3RC3.pdb', '3RC3_mod.pdb', '3RC8_mod.pdb']
#
# (84) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4E78
# Total 5 PDB files in 4E78 directory.
# All files in 4E78 directory:
# ['4E78.pdb', '4E76_mod.pdb', '4E78_4E76.pdb', '4E78_mod.pdb', '4E76.pdb']
#
# (85) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4J7M
# Total 5 PDB files in 4J7M directory.
# All files in 4J7M directory:
# ['4J7M_mod.pdb', '4J7N.pdb', '4J7M.pdb', '4J7M_4J7N.pdb', '4J7N_mod.pdb']
#
# (86) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/4N2Q
# Total 5 PDB files in 4N2Q directory.
# All files in 4N2Q directory:
# ['4N2Q.pdb', '4ME2_mod.pdb', '4N2Q_mod.pdb', '4ME2.pdb', '4N2Q_4ME2.pdb']
#
# (87) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5EIM
# Total 5 PDB files in 5EIM directory.
# All files in 5EIM directory:
# ['5H8A.pdb', '5EIM.pdb', '5H8A_mod.pdb', '5EIM_5H8A.pdb', '5EIM_mod.pdb']
#
# (88) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5EX7
# Total 5 PDB files in 5EX7 directory.
# All files in 5EX7 directory:
# ['4ZLR_mod.pdb', '4ZLR.pdb', '5EX7.pdb', '5EX7_4ZLR.pdb', '5EX7_mod.pdb']
#
# (89) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5GXH
# Total 5 PDB files in 5GXH directory.
# All files in 5GXH directory:
# ['5GXH_mod.pdb', '5GXH_5TEE.pdb', '5TEE.pdb', '5TEE_mod.pdb', '5GXH.pdb']
#
# (90) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5SZE
# Total 5 PDB files in 5SZE directory.
# All files in 5SZE directory:
# ['5SZE_mod.pdb', '5SZE_5SZD.pdb', '5SZD.pdb', '5SZE.pdb', '5SZD_mod.pdb']
#
# (91) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5V7C
# Total 5 PDB files in 5V7C directory.
# All files in 5V7C directory:
# ['5V7C.pdb', '5V7C_mod.pdb', '5V87.pdb', '5V7C_5V87.pdb', '5V87_mod.pdb']
#
# (92) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5W0M
# Total 5 PDB files in 5W0M directory.
# All files in 5W0M directory:
# ['5W0B_mod.pdb', '5W0M_5W0B.pdb', '5W0M.pdb', '5W0B.pdb', '5W0M_mod.pdb']
#
# (93) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5WWX
# Total 5 PDB files in 5WWX directory.
# All files in 5WWX directory:
# ['5WWX_mod.pdb', '5WWZ.pdb', '5WWX_5WWZ.pdb', '5WWX.pdb', '5WWZ_mod.pdb']
#
# (94) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5ZSC
# Total 5 PDB files in 5ZSC directory.
# All files in 5ZSC directory:
# ['6IF5.pdb', '5ZSC.pdb', '5ZSC_6IF5.pdb', '6IF5_mod.pdb', '5ZSC_mod.pdb']
#
# (95) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6A4E
# Total 5 PDB files in 6A4E directory.
# All files in 6A4E directory:
# ['6A4D_mod.pdb', '6A4D.pdb', '6A4E.pdb', '6A4E_6A4D.pdb', '6A4E_mod.pdb']
#
# (96) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6A6J
# Total 5 PDB files in 6A6J directory.
# All files in 6A6J directory:
# ['6A6J_6LMS.pdb', '6LMS.pdb', '6A6J.pdb', '6A6J_mod.pdb', '6LMS_mod.pdb']
#
# (97) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6GC5
# Total 5 PDB files in 6GC5 directory.
# All files in 6GC5 directory:
# ['6GC5_6GD1.pdb', '6GC5_mod.pdb', '6GD1.pdb', '6GC5.pdb', '6GD1_mod.pdb']
#
# (98) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6HAU
# Total 6 PDB files in 6HAU directory.
# All files in 6HAU directory:
# ['6HAT_mod.pdb', '6HAU_7HAT.pdb', '6HAT.pdb', '6HAU_6HAT.pdb', '6HAU.pdb', '6HAU_mod.pdb']
#
# (99) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6I0V
# Total 5 PDB files in 6I0V directory.
# All files in 6I0V directory:
# ['6I0S_mod.pdb', '6I0V_6I0S.pdb', '6I0V.pdb', '6I0S.pdb', '6I0V_mod.pdb']
#
# (100) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6LLB
# Total 5 PDB files in 6LLB directory.
# All files in 6LLB directory:
# ['5HAA.pdb', '6LLB_5HAA.pdb', '6LLB.pdb', '6LLB_mod.pdb', '5HAA_mod.pdb']
#
# (101) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6R9P
# Total 5 PDB files in 6R9P directory.
# All files in 6R9P directory:
# ['6R9I.pdb', '6R9P_mod.pdb', '6R9I_mod.pdb', '6R9P_6R9I.pdb', '6R9P.pdb']
#
# (102) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6L5N
# Total 5 PDB files in 6L5N directory.
# All files in 6L5N directory:
# ['6L5N_6L5M.pdb', '6L5M_mod.pdb', '6L5N.pdb', '6L5N_mod.pdb', '6L5M.pdb']
#
# (103) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6U6Y
# Total 5 PDB files in 6U6Y directory.
# All files in 6U6Y directory:
# ['6U6Y_5AO3.pdb', '5AO3_mod.pdb', '6U6Y_mod.pdb', '6U6Y.pdb', '5AO3.pdb']
#
# (104) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6WXY
# Total 5 PDB files in 6WXY directory.
# All files in 6WXY directory:
# ['6WXY_6WXW.pdb', '6WXY.pdb', '6WXY_mod.pdb', '6WXW_mod.pdb', '6WXW.pdb']
#
# (105) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6ZOT
# Total 5 PDB files in 6ZOT directory.
# All files in 6ZOT directory:
# ['8BS5.pdb', '8BS5_mod.pdb', '6ZOT_mod.pdb', '6ZOT_8BS5.pdb', '6ZOT.pdb']
#
# (106) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7DOL
# Total 5 PDB files in 7DOL directory.
# All files in 7DOL directory:
# ['7DOL_7DCY.pdb', '7DOL.pdb', '7DOL_mod.pdb', '7DCY_mod.pdb', '7DCY.pdb']
#
# (107) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7K5L
# Total 5 PDB files in 7K5L directory.
# All files in 7K5L directory:
# ['4LDM.pdb', '7K5L_4LDM.pdb', '4LDM_mod.pdb', '7K5L.pdb', '7K5L_mod.pdb']
#
# (108) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7EIU
# Total 5 PDB files in 7EIU directory.
# All files in 7EIU directory:
# ['7EIO.pdb', '7EIU.pdb', '7EIU_7EIO.pdb', '7EIO_mod.pdb', '7EIU_mod.pdb']
#
# (109) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7KL3
# Total 5 PDB files in 7KL3 directory.
# All files in 7KL3 directory:
# ['7KL3_5CZN.pdb', '5CZN.pdb', '5CZN_mod.pdb', '7KL3_mod.pdb', '7KL3.pdb']
#
# (110) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7L6T
# Total 5 PDB files in 7L6T directory.
# All files in 7L6T directory:
# ['7L6T_7C2I.pdb', '7L6T_mod.pdb', '7C2I.pdb', '7C2I_mod.pdb', '7L6T.pdb']
#
# (111) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7V4G
# Total 5 PDB files in 7V4G directory.
# All files in 7V4G directory:
# ['7V4G_4O61.pdb', '7V4G_mod.pdb', '7V4G.pdb', '4O61.pdb', '4O61_mod.pdb']
#
# (112) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7VSJ
# Total 5 PDB files in 7VSJ directory.
# All files in 7VSJ directory:
# ['7VSJ.pdb', '7VSJ_6FQ1.pdb', '7VSJ_mod.pdb', '6FQ1.pdb', '6FQ1_mod.pdb']
#
# (113) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7VKI
# Total 5 PDB files in 7VKI directory.
# All files in 7VKI directory:
# ['2DHA_mod.pdb', '7VKI.pdb', '7VKI_mod.pdb', '2DHA.pdb', '7VKI_2DHA.pdb']
#
# (114) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7VKL
# Total 5 PDB files in 7VKL directory.
# All files in 7VKL directory:
# ['6GQE.pdb', '6GQE_mod.pdb', '7VKL.pdb', '7VKL_mod.pdb', '7VKL_6GQE.pdb']
#
# (115) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7Y7Q
# Total 5 PDB files in 7Y7Q directory.
# All files in 7Y7Q directory:
# ['2J7N.pdb', '2J7N_mod.pdb', '7Y7Q_2J7N.pdb', '7Y7Q.pdb', '7Y7Q_mod.pdb']
#
# (116) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8DZK
# Total 5 PDB files in 8DZK directory.
# All files in 8DZK directory:
# ['8DZK_5K71.pdb', '8DZK.pdb', '5K71.pdb', '8DZK_mod.pdb', '5K71_mod.pdb']
#
# (117) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/8TG4
# Total 5 PDB files in 8TG4 directory.
# All files in 8TG4 directory:
# ['8TG3_mod.pdb', '8TG4_mod.pdb', '8TG3.pdb', '8TG4.pdb', '8TG4_8TG3.pdb']

# %%
print(f"Number of unique PDB ID in each docking case:\n{prdbv3_read_json['Docking_case'].value_counts()}\n")
# Out:
# Number of unique PDB ID in each docking case:
# Docking_case
# UB    160
# UU     27
# BU     10
# Name: count, dtype: int64

# %%
# Read PRDBv3 data directory and its contents based on the different docking cases
def get_PRDBv3_info_by_docking_case(path, df_to_parse, docking_case):
    print(f"INFO PRDBv3:\nTotal {len(df_to_parse[df_to_parse['Docking_case'] == docking_case]['C_PDB'].values)} directories in docking case {docking_case}: \n")
    # Iterate through each directory in the PRDBv3 dataset directory
    count_dir = 1
    for pdbdir in df_to_parse[df_to_parse['Docking_case'] == docking_case]['C_PDB'].values:
        try:
            print(f'({count_dir}) Directory path:{os.path.join(path, pdbdir)}')
            print(f'Total {len(os.listdir(os.path.join(path, pdbdir)))} PDB files in {pdbdir} directory.')
            print(f'All files in {pdbdir} directory:\n{os.listdir(os.path.join(path, pdbdir))}\n')
            count_dir += 1
            # Catch exception for directories not found
        except:
            print(f'Directory not found: {os.path.join(path, pdbdir)}\n')
# Read directories, files and its contents in PRDBv3 dataset directory based on docking case
get_PRDBv3_info_by_docking_case(PRDBv3_dir, prdbv3_read_json, 'UU')
# Out:
# INFO PRDBv3:
# Total 27 directories in docking case UU:
#
# (1) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ASY
# Total 8 PDB files in 1ASY directory.
# All files in 1ASY directory:
# ['2TRA.pdb', '1EOV.pdb', '1ASY_1EOV.pdb', '2TRA_mod.pdb', '1ASY_mod.pdb', '1ASY_2TRA.pdb', '1ASY.pdb', '1EOV_mod.pdb']
#
# (2) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1B23
# Total 8 PDB files in 1B23 directory.
# All files in 1B23 directory:
# ['1TUI_mod.pdb', '1B23.pdb', '1TUI.pdb', '1U0B.pdb', '1B23_mod.pdb', '1U0B_mod.pdb', '1B23_1TUI.pdb', '1B23_1U0B.pdb']
#
# (3) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1C0A
# Total 8 PDB files in 1C0A directory.
# All files in 1C0A directory:
# ['1C0A_1EQR.pdb', '1C0A.pdb', '1EQR_mod.pdb', '1C0A_1EFW.pdb', '1EFW.pdb', '1EFW_mod.pdb', '1C0A_mod.pdb', '1EQR.pdb']
#
# (4) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1QTQ
# Total 8 PDB files in 1QTQ directory.
# All files in 1QTQ directory:
# ['1QTQ_mod.pdb', '1NYL.pdb', '1QTQ.pdb', '1QTQ_3KNH.pdb', '3KNH_mod.pdb', '3KNH.pdb', '1NYL_mod.pdb', '1QTQ_1NYL.pdb']
#
# (5) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BTE
# Total 8 PDB files in 2BTE directory.
# All files in 2BTE directory:
# ['2NQP_mod.pdb', '2BTE_1OBC.pdb', '2NQP.pdb', '1OBC.pdb', '1OBC_mod.pdb', '2BTE.pdb', '2BTE_2NQP.pdb', '2BTE_mod.pdb']
#
# (6) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2DRB
# Total 8 PDB files in 2DRB directory.
# All files in 2DRB directory:
# ['1UET.pdb', '2DRB.pdb', '3Q1Q_mod.pdb', '3Q1Q.pdb', '2DRB_1UET.pdb', '2DRB_3Q1Q.pdb', '2DRB_mod.pdb', '1UET_mod.pdb']
#
# (7) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2FMT
# Total 8 PDB files in 2FMT directory.
# All files in 2FMT directory:
# ['1FMT.pdb', '3CW6.pdb', '2FMT_3CW6.pdb', '2FMT_1FMT.pdb', '2FMT_mod.pdb', '2FMT.pdb', '1FMT_mod.pdb', '3CW6_mod.pdb']
#
# (8) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2ZZM
# Total 8 PDB files in 2ZZM directory.
# All files in 2ZZM directory:
# ['2ZZM_mod.pdb', '2YX1.pdb', '2YX1_mod.pdb', '1WZ2.pdb', '2ZZM_1WZ2.pdb', '2ZZM.pdb', '2ZZM_2YX1.pdb', '1WZ2_mod.pdb']
#
# (9) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3HL2
# Total 8 PDB files in 3HL2 directory.
# All files in 3HL2 directory:
# ['3RG5_mod.pdb', '3HL2_mod.pdb', '3RG5.pdb', '3BC8_mod.pdb', '3HL2_3RG5.pdb', '3HL2.pdb', '3HL2_3BC8.pdb', '3BC8.pdb']
#
# (10) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3VJR
# Total 8 PDB files in 3VJR directory.
# All files in 3VJR directory:
# ['2PTH_mod.pdb', '1NJM_mod.pdb', '3VJR_mod.pdb', '3VJR_1NJM.pdb', '1NJM.pdb', '3VJR_2PTH.pdb', '2PTH.pdb', '3VJR.pdb']
#
# (11) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/5X6B
# Total 8 PDB files in 5X6B directory.
# All files in 5X6B directory:
# ['5X6B.pdb', '2ZZN_mod.pdb', '5X6B_mod.pdb', '2ZZN.pdb', '5X6B_2ZZN.pdb', '5X6B_3WKR.pdb', '3WKR.pdb', '3WKR_mod.pdb']
#
# (12) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/6LVR
# Total 8 PDB files in 6LVR directory.
# All files in 6LVR directory:
# ['4G24_mod.pdb', '6LVR.pdb', '1I9V_mod.pdb', '4G24.pdb', '1I9V.pdb', '6LVR_mod.pdb', '6LVR_4G24.pdb', '6LVR_1I9V.pdb']
#
# (13) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7YSE
# Total 8 PDB files in 7YSE directory.
# All files in 7YSE directory:
# ['7EIV.pdb', '7YSE_7EIV.pdb', '7YSE.pdb', '7EIV_mod.pdb', '7F36_mod.pdb', '7YSE_mod.pdb', '7F36.pdb', '7YSE_7F36.pdb']
#
# (14) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1DFU
# Total 8 PDB files in 1DFU directory.
# All files in 1DFU directory:
# ['1DFU_mod.pdb', '364D.pdb', '364D_mod.pdb', '1DFU_364D.pdb', '1B75.pdb', '1B75_mod.pdb', '1DFU_1B75.pdb', '1DFU.pdb']
#
# (15) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1FEU
# Total 8 PDB files in 1FEU directory.
# All files in 1FEU directory:
# ['364D.pdb', '364D_mod.pdb', '2J01.pdb', '1FEU.pdb', '2J01_mod.pdb', '1FEU_364D.pdb', '1FEU_mod.pdb', '1FEU_2J01.pdb']
#
# (16) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1MMS
# Total 8 PDB files in 1MMS directory.
# All files in 1MMS directory:
# ['1MMS_2K3F.pdb', '3I9C.pdb', '2K3F_mod.pdb', '1MMS_mod.pdb', '1MMS.pdb', '3I9C_mod.pdb', '2K3F.pdb', '1MMS_3I9C.pdb']
#
# (17) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3IEV
# Total 8 PDB files in 3IEV directory.
# All files in 3IEV directory:
# ['3IEV.pdb', '1SDR_mod.pdb', '3IEV_mod.pdb', '1SDR.pdb', '7C1O_mod.pdb', '3IEV_7C1O.pdb', '7C1O.pdb', '3IEV_1SDR.pdb']
#
# (18) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1OOA
# Total 8 PDB files in 1OOA directory.
# All files in 1OOA directory:
# ['1LE5_mod.pdb', '1LE5.pdb', '2JWV.pdb', '1OOA_mod.pdb', '2JWV_mod.pdb', '1OOA_2JWV.pdb', '1OOA.pdb', '1OOA_1LE5.pdb']
#
# (19) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1R3E
# Total 8 PDB files in 1R3E directory.
# All files in 1R3E directory:
# ['1EHZ_mod.pdb', '1ZE1.pdb', '1R3E.pdb', '1R3E_1ZE1.pdb', '1ZE1_mod.pdb', '1EHZ.pdb', '1R3E_1EHZ.pdb', '1R3E_mod.pdb']
#
# (20) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2R8S
# Total 8 PDB files in 2R8S directory.
# All files in 2R8S directory:
# ['1HR2.pdb', '2HFF.pdb', '2HFF_mod.pdb', '2R8S_2HFF.pdb', '2R8S.pdb', '2R8S_1HR2.pdb', '2R8S_mod.pdb', '1HR2_mod.pdb']
#
# (21) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/3SNP
# Total 8 PDB files in 3SNP directory.
# All files in 3SNP directory:
# ['3SNP_mod.pdb', '3SNP_2B3Y.pdb', '1AQO.pdb', '3SNP.pdb', '2B3Y_mod.pdb', '3SNP_1AQO.pdb', '2B3Y.pdb', '1AQO_mod.pdb']
#
# (22) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2OZB
# Total 8 PDB files in 2OZB directory.
# All files in 2OZB directory:
# ['2OZB_2JNB.pdb', '2OZB_2XEB.pdb', '2JNB_mod.pdb', '2XEB.pdb', '2OZB_mod.pdb', '2JNB.pdb', '2XEB_mod.pdb', '2OZB.pdb']
#
# (23) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/7P0V
# Total 8 PDB files in 7P0V directory.
# All files in 7P0V directory:
# ['7P0V.pdb', '8ID2_mod.pdb', '7P08.pdb', '7P0V_mod.pdb', '7P0V_8ID2.pdb', '7P08_mod.pdb', '7P0V_7P08.pdb', '8ID2.pdb']
#
# (24) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1JBS
# Total 8 PDB files in 1JBS directory.
# All files in 1JBS directory:
# ['1Q9A.pdb', '1Q9A_mod.pdb', '1JBS_1Q9A.pdb', '1JBS_1AQZ.pdb', '1AQZ.pdb', '1JBS.pdb', '1AQZ_mod.pdb', '1JBS_mod.pdb']
#
# (25) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1WSU
# Total 8 PDB files in 1WSU directory.
# All files in 1WSU directory:
# ['1WSU_mod.pdb', '1WSU_2RLU.pdb', '1LVA_mod.pdb', '2RLU_mod.pdb', '1WSU.pdb', '1LVA.pdb', '1WSU_1LVA.pdb', '2RLU.pdb']
#
# (26) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/1ZBH
# Total 8 PDB files in 1ZBH directory.
# All files in 1ZBH directory:
# ['1ZBH.pdb', '1JU7.pdb', '1ZBH_1ZBU.pdb', '1JU7_mod.pdb', '1ZBH_mod.pdb', '1ZBH_1JU7.pdb', '1ZBU_mod.pdb', '1ZBU.pdb']
#
# (27) Directory path:/home/shrikant/Projects/git_dev/PRDBv3_dataset/PRDBv3.0/2BH2
# Total 8 PDB files in 2BH2 directory.
# All files in 2BH2 directory:
# ['2BH2_1UWV.pdb', '1UWV.pdb', '1UWV_mod.pdb', '2BH2_mod.pdb', '1JZX.pdb', '2BH2.pdb', '1JZX_mod.pdb', '2BH2_1JZX.pdb']
