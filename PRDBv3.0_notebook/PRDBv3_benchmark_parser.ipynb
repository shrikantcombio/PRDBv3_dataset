# %% [markdown]
# # Tutorial PRDBv3.0 dataset

# %% [markdown]
# PYTHON LIBRARIES USED

# %%
import os
import sys
import numpy as np
import pandas as pd
import json
import lxml
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read json file

# %%
# Read the JSON file into a pandas DataFrame
prdbv3_read_json = pd.read_json('/home/shrikant/my_work/benchmark_work/Revision_1/PRDBv3_dataset/PRDBv3.0/PRDBv3_pdbList_chains.json')

# %%
prdbv3_read_json
# Out:
#     C_PDB C_chain_PR Structural_class Flexible_class Docking_case  \
# 0    1ASY        A:R                A              R           UU
# 1    1B23        P:R                A              F           UU
# 2    1C0A        A:B                A              S           UU
# 3    1QTQ        A:B                A              S           UU
# 4    2BTE        A:B                A              R           UU
# ..    ...        ...              ...            ...          ...
# 192  2PJP        A:B                C           None           BU
# 193  3BT7        A:C                C           None           BU
# 194  6HTU     ABC:DF                C           None           BU
# 195  1LNG        A:B                D           None           BU
# 196  2I82        A:E                D           None           BU
#
#     Binding_affinity C_pro_chain C_pro_seq_length C_RNA_chain  \
# 0                yes           A              490           R
# 1                 no           P              405           R
# 2                 no           A              585           B
# 3                yes           A              553           B
# 4                 no           A              878           B
# ..               ...         ...              ...         ...
# 192              yes           A              121           B
# 193              yes           A              369           C
# 194              yes         ABC      182+182+182          DF
# 195               no           A               87           B
# 196               no           A              217           E
#
#     C_RNA_seq_length U_pro_PDB U_pro_chain U_pro_seq_length U_RNA_PDB  \
# 0                 75      1EOV           A              487      2TRA
# 1                 74      1TUI           A              405     1U0B*
# 2                 77      1EQR           A              590     1EFW*
# 3                 75      1NYL           A              539     3KNH*
# 4                 83      1OBC           A              878     2NQP*
# ..               ...       ...         ...              ...       ...
# 192               23      None        None             None      1MFK
# 193               19      None        None             None      1EVV
# 194            19+19      None        None             None      6HU6
# 195               97      None        None             None      1Z43
# 196               21      None        None             None      3L0U
#
#     U_RNA_chain U_RNA_seq_length
# 0             A               75
# 1             A               74
# 2             C               73
# 3             Y               75
# 4             F               87
# ..          ...              ...
# 192           A               23
# 193           A               76
# 194          AE            19+19
# 195           A              101
# 196   A (26-43)               76
#
# [197 rows x 16 columns]

# %%
# Total number of unique domains in PRDBv3.0
print(f"Number of unique domains in PRDBv3: {prdbv3_read_json['C_PDB'].nunique()}\n")
# Number of unique PDB ID in each structural class
print(f"Number of unique PDB ID in each structural class:\n{prdbv3_read_json['Structural_class'].value_counts()}\n")
# Number of unique PDB ID in each flexible class
print(f"Number of unique PDB ID in each flexible class:\n{prdbv3_read_json['Flexible_class'].value_counts()}\n")
# Number of unique PDB ID in each docking case
print(f"Number of unique PDB ID in each docking case:\n{prdbv3_read_json['Docking_case'].value_counts()}\n")
# Out:
# Number of unique domains in PRDBv3: 197
#
# Number of unique PDB ID in each structural class:
# Structural_class
# D    86
# C    62
# A    40
# B     9
# Name: count, dtype: int64
#
# Number of unique PDB ID in each flexible class:
# Flexible_class
# R    117
# S     41
# F     29
# Name: count, dtype: int64
#
# Number of unique PDB ID in each docking case:
# Docking_case
# UB    160
# UU     27
# BU     10
# Name: count, dtype: int64

# %% [markdown]
# ## Read PDB files from PRDBv3.0 dataset

# %%
# PRDBv3 dataset directory
PRDBv3_dir = "PRDBv3_dataset/PRDBv3.0"

# %% [markdown]
# ### PRDBv3.0: List only directories from different classes

# %%
# List only directories
# List only directories in different classes
for root, dirs, files in os.walk(PRDBv3_dir):
    for dir in dirs:
        if dir in prdbv3_read_json.C_PDB.values:
            print(os.path.join(root, dir))

# %% [markdown]
# ### PRDBv3.0: List all files with directories

# %%
def get_PRDBv3_info(path, df_to_parse):
    print(f'INFO PRDBv3:\nTotal {len(df_to_parse)} directories in dataframe: \n')
    # Iterate through each directory in the PRDBv3 dataset directory
    count_dir = 1
    for pdbdir in df_to_parse['C_PDB'].values:
        try:
            print(f'({count_dir}) Directory path:{os.path.join(path, pdbdir)}')
            print(f'Total {len(os.listdir(os.path.join(path, pdbdir)))} PDB files in {pdbdir} directory.')
            print(f'All files in {pdbdir} directory:\n{os.listdir(os.path.join(path, pdbdir))}\n')
            count_dir += 1
            # Catch exception for directories not found
        except:
            print(f'Directory not found: {os.path.join(path, pdbdir)}\n')
# Read directories, files and its contents in PRDBv3 dataset directory
get_PRDBv3_info(PRDBv3_dir, prdbv3_read_json)
# Out:
# INFO PRDBv3:
# Total 197 directories in dataframe:
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1ASY
# Directory not found: PRDBv3_dataset/PRDBv3.0/1ASY
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1B23
# Directory not found: PRDBv3_dataset/PRDBv3.0/1B23
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1C0A
# Directory not found: PRDBv3_dataset/PRDBv3.0/1C0A
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1QTQ
# Directory not found: PRDBv3_dataset/PRDBv3.0/1QTQ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2BTE
# Directory not found: PRDBv3_dataset/PRDBv3.0/2BTE
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2DRB
# Directory not found: PRDBv3_dataset/PRDBv3.0/2DRB
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2FMT
# Directory not found: PRDBv3_dataset/PRDBv3.0/2FMT
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2ZZM
# Directory not found: PRDBv3_dataset/PRDBv3.0/2ZZM
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3HL2
# Directory not found: PRDBv3_dataset/PRDBv3.0/3HL2
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3VJR
# Directory not found: PRDBv3_dataset/PRDBv3.0/3VJR
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5X6B
# Directory not found: PRDBv3_dataset/PRDBv3.0/5X6B
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6LVR
# Directory not found: PRDBv3_dataset/PRDBv3.0/6LVR
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7YSE
# Directory not found: PRDBv3_dataset/PRDBv3.0/7YSE
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1DFU
# Directory not found: PRDBv3_dataset/PRDBv3.0/1DFU
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1FEU
# Directory not found: PRDBv3_dataset/PRDBv3.0/1FEU
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1MMS
# Directory not found: PRDBv3_dataset/PRDBv3.0/1MMS
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3IEV
# Directory not found: PRDBv3_dataset/PRDBv3.0/3IEV
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1OOA
# Directory not found: PRDBv3_dataset/PRDBv3.0/1OOA
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1R3E
# Directory not found: PRDBv3_dataset/PRDBv3.0/1R3E
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2R8S
# Directory not found: PRDBv3_dataset/PRDBv3.0/2R8S
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3SNP
# Directory not found: PRDBv3_dataset/PRDBv3.0/3SNP
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2OZB
# Directory not found: PRDBv3_dataset/PRDBv3.0/2OZB
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7P0V
# Directory not found: PRDBv3_dataset/PRDBv3.0/7P0V
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1JBS
# Directory not found: PRDBv3_dataset/PRDBv3.0/1JBS
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1WSU
# Directory not found: PRDBv3_dataset/PRDBv3.0/1WSU
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1ZBH
# Directory not found: PRDBv3_dataset/PRDBv3.0/1ZBH
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2BH2
# Directory not found: PRDBv3_dataset/PRDBv3.0/2BH2
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1F7U
# Directory not found: PRDBv3_dataset/PRDBv3.0/1F7U
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1H3E
# Directory not found: PRDBv3_dataset/PRDBv3.0/1H3E
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1H4S
# Directory not found: PRDBv3_dataset/PRDBv3.0/1H4S
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1J1U
# Directory not found: PRDBv3_dataset/PRDBv3.0/1J1U
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1N78
# Directory not found: PRDBv3_dataset/PRDBv3.0/1N78
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1QF6
# Directory not found: PRDBv3_dataset/PRDBv3.0/1QF6
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1SER
# Directory not found: PRDBv3_dataset/PRDBv3.0/1SER
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1U0B
# Directory not found: PRDBv3_dataset/PRDBv3.0/1U0B
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1VFG
# Directory not found: PRDBv3_dataset/PRDBv3.0/1VFG
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2AZX
# Directory not found: PRDBv3_dataset/PRDBv3.0/2AZX
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2FK6
# Directory not found: PRDBv3_dataset/PRDBv3.0/2FK6
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3ADB
# Directory not found: PRDBv3_dataset/PRDBv3.0/3ADB
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3AMT
# Directory not found: PRDBv3_dataset/PRDBv3.0/3AMT
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4YCP
# Directory not found: PRDBv3_dataset/PRDBv3.0/4YCP
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4YVJ
# Directory not found: PRDBv3_dataset/PRDBv3.0/4YVJ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5HR7
# Directory not found: PRDBv3_dataset/PRDBv3.0/5HR7
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5B63
# Directory not found: PRDBv3_dataset/PRDBv3.0/5B63
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5T8Y
# Directory not found: PRDBv3_dataset/PRDBv3.0/5T8Y
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5WT1
# Directory not found: PRDBv3_dataset/PRDBv3.0/5WT1
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5ZW4
# Directory not found: PRDBv3_dataset/PRDBv3.0/5ZW4
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7E8O
# Directory not found: PRDBv3_dataset/PRDBv3.0/7E8O
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7K98
# Directory not found: PRDBv3_dataset/PRDBv3.0/7K98
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7MJW
# Directory not found: PRDBv3_dataset/PRDBv3.0/7MJW
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/8H1B
# Directory not found: PRDBv3_dataset/PRDBv3.0/8H1B
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/8JOZ
# Directory not found: PRDBv3_dataset/PRDBv3.0/8JOZ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1G1X
# Directory not found: PRDBv3_dataset/PRDBv3.0/1G1X
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1SDS
# Directory not found: PRDBv3_dataset/PRDBv3.0/1SDS
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2HW8
# Directory not found: PRDBv3_dataset/PRDBv3.0/2HW8
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5WTY
# Directory not found: PRDBv3_dataset/PRDBv3.0/5WTY
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1MSW
# Directory not found: PRDBv3_dataset/PRDBv3.0/1MSW
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1N35
# Directory not found: PRDBv3_dataset/PRDBv3.0/1N35
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1Q2R
# Directory not found: PRDBv3_dataset/PRDBv3.0/1Q2R
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1WNE
# Directory not found: PRDBv3_dataset/PRDBv3.0/1WNE
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1YVP
# Directory not found: PRDBv3_dataset/PRDBv3.0/1YVP
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1ZBI
# Directory not found: PRDBv3_dataset/PRDBv3.0/1ZBI
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2AZ0
# Directory not found: PRDBv3_dataset/PRDBv3.0/2AZ0
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2BGG
# Directory not found: PRDBv3_dataset/PRDBv3.0/2BGG
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2EZ6
# Directory not found: PRDBv3_dataset/PRDBv3.0/2EZ6
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2F8S
# Directory not found: PRDBv3_dataset/PRDBv3.0/2F8S
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2GJW
# Directory not found: PRDBv3_dataset/PRDBv3.0/2GJW
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2GXB
# Directory not found: PRDBv3_dataset/PRDBv3.0/2GXB
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2QUX
# Directory not found: PRDBv3_dataset/PRDBv3.0/2QUX
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2Y8W
# Directory not found: PRDBv3_dataset/PRDBv3.0/2Y8W
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2ZKO
# Directory not found: PRDBv3_dataset/PRDBv3.0/2ZKO
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3A6P
# Directory not found: PRDBv3_dataset/PRDBv3.0/3A6P
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3BSN
# Directory not found: PRDBv3_dataset/PRDBv3.0/3BSN
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3DD2
# Directory not found: PRDBv3_dataset/PRDBv3.0/3DD2
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3EQT
# Directory not found: PRDBv3_dataset/PRDBv3.0/3EQT
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3FTE
# Directory not found: PRDBv3_dataset/PRDBv3.0/3FTE
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3KS8
# Directory not found: PRDBv3_dataset/PRDBv3.0/3KS8
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3MOJ
# Directory not found: PRDBv3_dataset/PRDBv3.0/3MOJ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3O3I
# Directory not found: PRDBv3_dataset/PRDBv3.0/3O3I
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3OIJ
# Directory not found: PRDBv3_dataset/PRDBv3.0/3OIJ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3OL6
# Directory not found: PRDBv3_dataset/PRDBv3.0/3OL6
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3RW6
# Directory not found: PRDBv3_dataset/PRDBv3.0/3RW6
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3ZC0
# Directory not found: PRDBv3_dataset/PRDBv3.0/3ZC0
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4ERD
# Directory not found: PRDBv3_dataset/PRDBv3.0/4ERD
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4FVU
# Directory not found: PRDBv3_dataset/PRDBv3.0/4FVU
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4IG8
# Directory not found: PRDBv3_dataset/PRDBv3.0/4IG8
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4ILL
# Directory not found: PRDBv3_dataset/PRDBv3.0/4ILL
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4ZT0
# Directory not found: PRDBv3_dataset/PRDBv3.0/4ZT0
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5ED1
# Directory not found: PRDBv3_dataset/PRDBv3.0/5ED1
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5F5H
# Directory not found: PRDBv3_dataset/PRDBv3.0/5F5H
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5WTK
# Directory not found: PRDBv3_dataset/PRDBv3.0/5WTK
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5ZQ8
# Directory not found: PRDBv3_dataset/PRDBv3.0/5ZQ8
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6D12
# Directory not found: PRDBv3_dataset/PRDBv3.0/6D12
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6DCB
# Directory not found: PRDBv3_dataset/PRDBv3.0/6DCB
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6FQ3
# Directory not found: PRDBv3_dataset/PRDBv3.0/6FQ3
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6SY4
# Directory not found: PRDBv3_dataset/PRDBv3.0/6SY4
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6PZQ
# Directory not found: PRDBv3_dataset/PRDBv3.0/6PZQ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6RTI
# Directory not found: PRDBv3_dataset/PRDBv3.0/6RTI
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6ZDP
# Directory not found: PRDBv3_dataset/PRDBv3.0/6ZDP
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7KFN
# Directory not found: PRDBv3_dataset/PRDBv3.0/7KFN
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7KKV
# Directory not found: PRDBv3_dataset/PRDBv3.0/7KKV
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7OG0
# Directory not found: PRDBv3_dataset/PRDBv3.0/7OG0
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7OM6
# Directory not found: PRDBv3_dataset/PRDBv3.0/7OM6
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7XD8
# Directory not found: PRDBv3_dataset/PRDBv3.0/7XD8
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7XWZ
# Directory not found: PRDBv3_dataset/PRDBv3.0/7XWZ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7ZLQ
# Directory not found: PRDBv3_dataset/PRDBv3.0/7ZLQ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/8AF0
# Directory not found: PRDBv3_dataset/PRDBv3.0/8AF0
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1AV6
# Directory not found: PRDBv3_dataset/PRDBv3.0/1AV6
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1C9S
# Directory not found: PRDBv3_dataset/PRDBv3.0/1C9S
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1CVJ
# Directory not found: PRDBv3_dataset/PRDBv3.0/1CVJ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1G2E
# Directory not found: PRDBv3_dataset/PRDBv3.0/1G2E
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1K8W
# Directory not found: PRDBv3_dataset/PRDBv3.0/1K8W
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1KQ2
# Directory not found: PRDBv3_dataset/PRDBv3.0/1KQ2
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1M5O
# Directory not found: PRDBv3_dataset/PRDBv3.0/1M5O
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1M8V
# Directory not found: PRDBv3_dataset/PRDBv3.0/1M8V
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1M8W
# Directory not found: PRDBv3_dataset/PRDBv3.0/1M8W
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1UVI
# Directory not found: PRDBv3_dataset/PRDBv3.0/1UVI
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1WPU
# Directory not found: PRDBv3_dataset/PRDBv3.0/1WPU
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2A8V
# Directory not found: PRDBv3_dataset/PRDBv3.0/2A8V
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2ASB
# Directory not found: PRDBv3_dataset/PRDBv3.0/2ASB
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2GIC
# Directory not found: PRDBv3_dataset/PRDBv3.0/2GIC
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2IX1
# Directory not found: PRDBv3_dataset/PRDBv3.0/2IX1
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2JEA
# Directory not found: PRDBv3_dataset/PRDBv3.0/2JEA
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2JLU
# Directory not found: PRDBv3_dataset/PRDBv3.0/2JLU
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2PY9
# Directory not found: PRDBv3_dataset/PRDBv3.0/2PY9
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2Q66
# Directory not found: PRDBv3_dataset/PRDBv3.0/2Q66
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2R7R
# Directory not found: PRDBv3_dataset/PRDBv3.0/2R7R
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2XGJ
# Directory not found: PRDBv3_dataset/PRDBv3.0/2XGJ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2XNR
# Directory not found: PRDBv3_dataset/PRDBv3.0/2XNR
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2XZO
# Directory not found: PRDBv3_dataset/PRDBv3.0/2XZO
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3AEV
# Directory not found: PRDBv3_dataset/PRDBv3.0/3AEV
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3BX2
# Directory not found: PRDBv3_dataset/PRDBv3.0/3BX2
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3D2S
# Directory not found: PRDBv3_dataset/PRDBv3.0/3D2S
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3MDG
# Directory not found: PRDBv3_dataset/PRDBv3.0/3MDG
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3NMR
# Directory not found: PRDBv3_dataset/PRDBv3.0/3NMR
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3O8C
# Directory not found: PRDBv3_dataset/PRDBv3.0/3O8C
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3PF4
# Directory not found: PRDBv3_dataset/PRDBv3.0/3PF4
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3QJJ
# Directory not found: PRDBv3_dataset/PRDBv3.0/3QJJ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3RC8
# Directory not found: PRDBv3_dataset/PRDBv3.0/3RC8
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4E78
# Directory not found: PRDBv3_dataset/PRDBv3.0/4E78
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4H5P
# Directory not found: PRDBv3_dataset/PRDBv3.0/4H5P
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4HOR
# Directory not found: PRDBv3_dataset/PRDBv3.0/4HOR
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4J7M
# Directory not found: PRDBv3_dataset/PRDBv3.0/4J7M
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4M59
# Directory not found: PRDBv3_dataset/PRDBv3.0/4M59
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4MDX
# Directory not found: PRDBv3_dataset/PRDBv3.0/4MDX
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4N2Q
# Directory not found: PRDBv3_dataset/PRDBv3.0/4N2Q
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/4QU6
# Directory not found: PRDBv3_dataset/PRDBv3.0/4QU6
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5DET
# Directory not found: PRDBv3_dataset/PRDBv3.0/5DET
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5EIM
# Directory not found: PRDBv3_dataset/PRDBv3.0/5EIM
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5ELS
# Directory not found: PRDBv3_dataset/PRDBv3.0/5ELS
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5EX7
# Directory not found: PRDBv3_dataset/PRDBv3.0/5EX7
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5GXH
# Directory not found: PRDBv3_dataset/PRDBv3.0/5GXH
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5LTA
# Directory not found: PRDBv3_dataset/PRDBv3.0/5LTA
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5SZE
# Directory not found: PRDBv3_dataset/PRDBv3.0/5SZE
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5V7C
# Directory not found: PRDBv3_dataset/PRDBv3.0/5V7C
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5W0M
# Directory not found: PRDBv3_dataset/PRDBv3.0/5W0M
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5WWX
# Directory not found: PRDBv3_dataset/PRDBv3.0/5WWX
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/5ZSC
# Directory not found: PRDBv3_dataset/PRDBv3.0/5ZSC
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6A4E
# Directory not found: PRDBv3_dataset/PRDBv3.0/6A4E
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6A6J
# Directory not found: PRDBv3_dataset/PRDBv3.0/6A6J
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6GC5
# Directory not found: PRDBv3_dataset/PRDBv3.0/6GC5
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6HAU
# Directory not found: PRDBv3_dataset/PRDBv3.0/6HAU
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6I0V
# Directory not found: PRDBv3_dataset/PRDBv3.0/6I0V
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6L1W
# Directory not found: PRDBv3_dataset/PRDBv3.0/6L1W
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6LLB
# Directory not found: PRDBv3_dataset/PRDBv3.0/6LLB
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6R9P
# Directory not found: PRDBv3_dataset/PRDBv3.0/6R9P
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6U9X
# Directory not found: PRDBv3_dataset/PRDBv3.0/6U9X
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6L5N
# Directory not found: PRDBv3_dataset/PRDBv3.0/6L5N
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6LT7
# Directory not found: PRDBv3_dataset/PRDBv3.0/6LT7
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6U6Y
# Directory not found: PRDBv3_dataset/PRDBv3.0/6U6Y
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6WXY
# Directory not found: PRDBv3_dataset/PRDBv3.0/6WXY
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6ZOT
# Directory not found: PRDBv3_dataset/PRDBv3.0/6ZOT
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7C45
# Directory not found: PRDBv3_dataset/PRDBv3.0/7C45
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7DOL
# Directory not found: PRDBv3_dataset/PRDBv3.0/7DOL
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7K5L
# Directory not found: PRDBv3_dataset/PRDBv3.0/7K5L
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7EIU
# Directory not found: PRDBv3_dataset/PRDBv3.0/7EIU
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7KL3
# Directory not found: PRDBv3_dataset/PRDBv3.0/7KL3
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7L6T
# Directory not found: PRDBv3_dataset/PRDBv3.0/7L6T
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7V4G
# Directory not found: PRDBv3_dataset/PRDBv3.0/7V4G
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7VSJ
# Directory not found: PRDBv3_dataset/PRDBv3.0/7VSJ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7VKI
# Directory not found: PRDBv3_dataset/PRDBv3.0/7VKI
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7VKL
# Directory not found: PRDBv3_dataset/PRDBv3.0/7VKL
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/7Y7Q
# Directory not found: PRDBv3_dataset/PRDBv3.0/7Y7Q
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/8DZK
# Directory not found: PRDBv3_dataset/PRDBv3.0/8DZK
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/8EDJ
# Directory not found: PRDBv3_dataset/PRDBv3.0/8EDJ
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/8AXF
# Directory not found: PRDBv3_dataset/PRDBv3.0/8AXF
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/8TG4
# Directory not found: PRDBv3_dataset/PRDBv3.0/8TG4
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2ZM5
# Directory not found: PRDBv3_dataset/PRDBv3.0/2ZM5
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3ZJT
# Directory not found: PRDBv3_dataset/PRDBv3.0/3ZJT
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6AAX
# Directory not found: PRDBv3_dataset/PRDBv3.0/6AAX
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1HQ1
# Directory not found: PRDBv3_dataset/PRDBv3.0/1HQ1
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1JID
# Directory not found: PRDBv3_dataset/PRDBv3.0/1JID
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2PJP
# Directory not found: PRDBv3_dataset/PRDBv3.0/2PJP
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/3BT7
# Directory not found: PRDBv3_dataset/PRDBv3.0/3BT7
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/6HTU
# Directory not found: PRDBv3_dataset/PRDBv3.0/6HTU
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/1LNG
# Directory not found: PRDBv3_dataset/PRDBv3.0/1LNG
#
# (1) Directory path:PRDBv3_dataset/PRDBv3.0/2I82
# Directory not found: PRDBv3_dataset/PRDBv3.0/2I82

# %%
print(f"Number of unique PDB ID in each structural class:\n{prdbv3_read_json['Structural_class'].value_counts()}\n")
# Out:
# Number of unique PDB ID in each structural class:
# Structural_class
# D    86
# C    62
# A    40
# B     9
# Name: count, dtype: int64

# %%
# Read PRDBv3 data directory and its contents based on the different structural classes
def get_PRDBv3_info_by_class(path, df_to_parse, class_name):
    print(f"INFO PRDBv3:\nTotal {len(df_to_parse[df_to_parse['Structural_class'] == class_name]['C_PDB'].values)} directories in clas {class_name}: \n")
    # Iterate through each directory in the PRDBv3 dataset directory
    count_dir = 1
    for pdbdir in df_to_parse[df_to_parse['Structural_class'] == class_name]['C_PDB'].values:
        try:
            print(f'({count_dir}) Directory path:{os.path.join(path, pdbdir)}')
            print(f'Total {len(os.listdir(os.path.join(path, pdbdir)))} PDB files in {pdbdir} directory.')
            print(f'All files in {pdbdir} directory:\n{os.listdir(os.path.join(path, pdbdir))}\n')
            count_dir += 1
            # Catch exception for directories not found
        except:
            print(f'Directory not found: {os.path.join(path, pdbdir)}\n')
    
# Read directories, files and its contents in PRDBv3 dataset directory based on structural class
get_PRDBv3_info_by_class(PRDBv3_dir, prdbv3_read_json, 'A')
# Out:
# INFO PRDBv3:
# Total 40 directories in clas A:
#
# (1) Directory path:PRDBv3.0/1ASY
# Directory not found: PRDBv3.0/1ASY
#
# (1) Directory path:PRDBv3.0/1B23
# Directory not found: PRDBv3.0/1B23
#
# (1) Directory path:PRDBv3.0/1C0A
# Directory not found: PRDBv3.0/1C0A
#
# (1) Directory path:PRDBv3.0/1QTQ
# Directory not found: PRDBv3.0/1QTQ
#
# (1) Directory path:PRDBv3.0/2BTE
# Directory not found: PRDBv3.0/2BTE
#
# (1) Directory path:PRDBv3.0/2DRB
# Directory not found: PRDBv3.0/2DRB
#
# (1) Directory path:PRDBv3.0/2FMT
# Directory not found: PRDBv3.0/2FMT
#
# (1) Directory path:PRDBv3.0/2ZZM
# Directory not found: PRDBv3.0/2ZZM
#
# (1) Directory path:PRDBv3.0/3HL2
# Directory not found: PRDBv3.0/3HL2
#
# (1) Directory path:PRDBv3.0/3VJR
# Directory not found: PRDBv3.0/3VJR
#
# (1) Directory path:PRDBv3.0/5X6B
# Directory not found: PRDBv3.0/5X6B
#
# (1) Directory path:PRDBv3.0/6LVR
# Directory not found: PRDBv3.0/6LVR
#
# (1) Directory path:PRDBv3.0/7YSE
# Directory not found: PRDBv3.0/7YSE
#
# (1) Directory path:PRDBv3.0/1F7U
# Directory not found: PRDBv3.0/1F7U
#
# (1) Directory path:PRDBv3.0/1H3E
# Directory not found: PRDBv3.0/1H3E
#
# (1) Directory path:PRDBv3.0/1H4S
# Directory not found: PRDBv3.0/1H4S
#
# (1) Directory path:PRDBv3.0/1J1U
# Directory not found: PRDBv3.0/1J1U
#
# (1) Directory path:PRDBv3.0/1N78
# Directory not found: PRDBv3.0/1N78
#
# (1) Directory path:PRDBv3.0/1QF6
# Directory not found: PRDBv3.0/1QF6
#
# (1) Directory path:PRDBv3.0/1SER
# Directory not found: PRDBv3.0/1SER
#
# (1) Directory path:PRDBv3.0/1U0B
# Directory not found: PRDBv3.0/1U0B
#
# (1) Directory path:PRDBv3.0/1VFG
# Directory not found: PRDBv3.0/1VFG
#
# (1) Directory path:PRDBv3.0/2AZX
# Directory not found: PRDBv3.0/2AZX
#
# (1) Directory path:PRDBv3.0/2FK6
# Directory not found: PRDBv3.0/2FK6
#
# (1) Directory path:PRDBv3.0/3ADB
# Directory not found: PRDBv3.0/3ADB
#
# (1) Directory path:PRDBv3.0/3AMT
# Directory not found: PRDBv3.0/3AMT
#
# (1) Directory path:PRDBv3.0/4YCP
# Directory not found: PRDBv3.0/4YCP
#
# (1) Directory path:PRDBv3.0/4YVJ
# Directory not found: PRDBv3.0/4YVJ
#
# (1) Directory path:PRDBv3.0/5HR7
# Directory not found: PRDBv3.0/5HR7
#
# (1) Directory path:PRDBv3.0/5B63
# Directory not found: PRDBv3.0/5B63
#
# (1) Directory path:PRDBv3.0/5T8Y
# Directory not found: PRDBv3.0/5T8Y
#
# (1) Directory path:PRDBv3.0/5WT1
# Directory not found: PRDBv3.0/5WT1
#
# (1) Directory path:PRDBv3.0/5ZW4
# Directory not found: PRDBv3.0/5ZW4
#
# (1) Directory path:PRDBv3.0/7E8O
# Directory not found: PRDBv3.0/7E8O
#
# (1) Directory path:PRDBv3.0/7K98
# Directory not found: PRDBv3.0/7K98
#
# (1) Directory path:PRDBv3.0/7MJW
# Directory not found: PRDBv3.0/7MJW
#
# (1) Directory path:PRDBv3.0/8H1B
# Directory not found: PRDBv3.0/8H1B
#
# (1) Directory path:PRDBv3.0/8JOZ
# Directory not found: PRDBv3.0/8JOZ
#
# (1) Directory path:PRDBv3.0/2ZM5
# Directory not found: PRDBv3.0/2ZM5
#
# (1) Directory path:PRDBv3.0/3ZJT
# Directory not found: PRDBv3.0/3ZJT

# %%
print(f"Number of unique PDB ID in each flexible class:\n{prdbv3_read_json['Flexible_class'].value_counts()}\n")
# Out:
# Number of unique PDB ID in each flexible class:
# Flexible_class
# R    117
# S     41
# F     29
# Name: count, dtype: int64

# %%
# Read PRDBv3 data directory and its contents based on the different flexible class
def get_PRDBv3_info_by_flexible_class(path, df_to_parse, flex_class):
    print(f"INFO PRDBv3:\nTotal {len(df_to_parse[df_to_parse['Flexible_class'] == flex_class]['C_PDB'].values)} directories in flexible class {flex_class}: \n")
    # Iterate through each directory in the PRDBv3 dataset directory
    count_dir = 1
    for pdbdir in df_to_parse[df_to_parse['Flexible_class'] == flex_class]['C_PDB'].values:
        try:
            print(f'({count_dir}) Directory path:{os.path.join(path, pdbdir)}')
            print(f'Total {len(os.listdir(os.path.join(path, pdbdir)))} PDB files in {pdbdir} directory.')
            print(f'All files in {pdbdir} directory:\n{os.listdir(os.path.join(path, pdbdir))}\n')
            count_dir += 1
            # Catch exception for directories not found
        except:
            print(f'Directory not found: {os.path.join(path, pdbdir)}\n')
# Read directories, files and its contents in PRDBv3 dataset directory based on flexible class
get_PRDBv3_info_by_flexible_class(PRDBv3_dir, prdbv3_read_json, 'R')
# Out:
# INFO PRDBv3:
# Total 117 directories in flexible class R:
#
# (1) Directory path:PRDBv3.0/1ASY
# Directory not found: PRDBv3.0/1ASY
#
# (1) Directory path:PRDBv3.0/2BTE
# Directory not found: PRDBv3.0/2BTE
#
# (1) Directory path:PRDBv3.0/2FMT
# Directory not found: PRDBv3.0/2FMT
#
# (1) Directory path:PRDBv3.0/3HL2
# Directory not found: PRDBv3.0/3HL2
#
# (1) Directory path:PRDBv3.0/3VJR
# Directory not found: PRDBv3.0/3VJR
#
# (1) Directory path:PRDBv3.0/5X6B
# Directory not found: PRDBv3.0/5X6B
#
# (1) Directory path:PRDBv3.0/3IEV
# Directory not found: PRDBv3.0/3IEV
#
# (1) Directory path:PRDBv3.0/1JBS
# Directory not found: PRDBv3.0/1JBS
#
# (1) Directory path:PRDBv3.0/1WSU
# Directory not found: PRDBv3.0/1WSU
#
# (1) Directory path:PRDBv3.0/1ZBH
# Directory not found: PRDBv3.0/1ZBH
#
# (1) Directory path:PRDBv3.0/2BH2
# Directory not found: PRDBv3.0/2BH2
#
# (1) Directory path:PRDBv3.0/1H4S
# Directory not found: PRDBv3.0/1H4S
#
# (1) Directory path:PRDBv3.0/1J1U
# Directory not found: PRDBv3.0/1J1U
#
# (1) Directory path:PRDBv3.0/1N78
# Directory not found: PRDBv3.0/1N78
#
# (1) Directory path:PRDBv3.0/1QF6
# Directory not found: PRDBv3.0/1QF6
#
# (1) Directory path:PRDBv3.0/1U0B
# Directory not found: PRDBv3.0/1U0B
#
# (1) Directory path:PRDBv3.0/1VFG
# Directory not found: PRDBv3.0/1VFG
#
# (1) Directory path:PRDBv3.0/2AZX
# Directory not found: PRDBv3.0/2AZX
#
# (1) Directory path:PRDBv3.0/2FK6
# Directory not found: PRDBv3.0/2FK6
#
# (1) Directory path:PRDBv3.0/3AMT
# Directory not found: PRDBv3.0/3AMT
#
# (1) Directory path:PRDBv3.0/4YVJ
# Directory not found: PRDBv3.0/4YVJ
#
# (1) Directory path:PRDBv3.0/5HR7
# Directory not found: PRDBv3.0/5HR7
#
# (1) Directory path:PRDBv3.0/5T8Y
# Directory not found: PRDBv3.0/5T8Y
#
# (1) Directory path:PRDBv3.0/5ZW4
# Directory not found: PRDBv3.0/5ZW4
#
# (1) Directory path:PRDBv3.0/7E8O
# Directory not found: PRDBv3.0/7E8O
#
# (1) Directory path:PRDBv3.0/8JOZ
# Directory not found: PRDBv3.0/8JOZ
#
# (1) Directory path:PRDBv3.0/1G1X
# Directory not found: PRDBv3.0/1G1X
#
# (1) Directory path:PRDBv3.0/1SDS
# Directory not found: PRDBv3.0/1SDS
#
# (1) Directory path:PRDBv3.0/1N35
# Directory not found: PRDBv3.0/1N35
#
# (1) Directory path:PRDBv3.0/1WNE
# Directory not found: PRDBv3.0/1WNE
#
# (1) Directory path:PRDBv3.0/1YVP
# Directory not found: PRDBv3.0/1YVP
#
# (1) Directory path:PRDBv3.0/1ZBI
# Directory not found: PRDBv3.0/1ZBI
#
# (1) Directory path:PRDBv3.0/2AZ0
# Directory not found: PRDBv3.0/2AZ0
#
# (1) Directory path:PRDBv3.0/2BGG
# Directory not found: PRDBv3.0/2BGG
#
# (1) Directory path:PRDBv3.0/2EZ6
# Directory not found: PRDBv3.0/2EZ6
#
# (1) Directory path:PRDBv3.0/2GJW
# Directory not found: PRDBv3.0/2GJW
#
# (1) Directory path:PRDBv3.0/2GXB
# Directory not found: PRDBv3.0/2GXB
#
# (1) Directory path:PRDBv3.0/2QUX
# Directory not found: PRDBv3.0/2QUX
#
# (1) Directory path:PRDBv3.0/2ZKO
# Directory not found: PRDBv3.0/2ZKO
#
# (1) Directory path:PRDBv3.0/3A6P
# Directory not found: PRDBv3.0/3A6P
#
# (1) Directory path:PRDBv3.0/3DD2
# Directory not found: PRDBv3.0/3DD2
#
# (1) Directory path:PRDBv3.0/3EQT
# Directory not found: PRDBv3.0/3EQT
#
# (1) Directory path:PRDBv3.0/3FTE
# Directory not found: PRDBv3.0/3FTE
#
# (1) Directory path:PRDBv3.0/3KS8
# Directory not found: PRDBv3.0/3KS8
#
# (1) Directory path:PRDBv3.0/3MOJ
# Directory not found: PRDBv3.0/3MOJ
#
# (1) Directory path:PRDBv3.0/3OL6
# Directory not found: PRDBv3.0/3OL6
#
# (1) Directory path:PRDBv3.0/3ZC0
# Directory not found: PRDBv3.0/3ZC0
#
# (1) Directory path:PRDBv3.0/4ERD
# Directory not found: PRDBv3.0/4ERD
#
# (1) Directory path:PRDBv3.0/4FVU
# Directory not found: PRDBv3.0/4FVU
#
# (1) Directory path:PRDBv3.0/4ILL
# Directory not found: PRDBv3.0/4ILL
#
# (1) Directory path:PRDBv3.0/5F5H
# Directory not found: PRDBv3.0/5F5H
#
# (1) Directory path:PRDBv3.0/5ZQ8
# Directory not found: PRDBv3.0/5ZQ8
#
# (1) Directory path:PRDBv3.0/6DCB
# Directory not found: PRDBv3.0/6DCB
#
# (1) Directory path:PRDBv3.0/6PZQ
# Directory not found: PRDBv3.0/6PZQ
#
# (1) Directory path:PRDBv3.0/6RTI
# Directory not found: PRDBv3.0/6RTI
#
# (1) Directory path:PRDBv3.0/7KKV
# Directory not found: PRDBv3.0/7KKV
#
# (1) Directory path:PRDBv3.0/7OM6
# Directory not found: PRDBv3.0/7OM6
#
# (1) Directory path:PRDBv3.0/7ZLQ
# Directory not found: PRDBv3.0/7ZLQ
#
# (1) Directory path:PRDBv3.0/8AF0
# Directory not found: PRDBv3.0/8AF0
#
# (1) Directory path:PRDBv3.0/1AV6
# Directory not found: PRDBv3.0/1AV6
#
# (1) Directory path:PRDBv3.0/1C9S
# Directory not found: PRDBv3.0/1C9S
#
# (1) Directory path:PRDBv3.0/1G2E
# Directory not found: PRDBv3.0/1G2E
#
# (1) Directory path:PRDBv3.0/1K8W
# Directory not found: PRDBv3.0/1K8W
#
# (1) Directory path:PRDBv3.0/1KQ2
# Directory not found: PRDBv3.0/1KQ2
#
# (1) Directory path:PRDBv3.0/1M5O
# Directory not found: PRDBv3.0/1M5O
#
# (1) Directory path:PRDBv3.0/1M8V
# Directory not found: PRDBv3.0/1M8V
#
# (1) Directory path:PRDBv3.0/1M8W
# Directory not found: PRDBv3.0/1M8W
#
# (1) Directory path:PRDBv3.0/1UVI
# Directory not found: PRDBv3.0/1UVI
#
# (1) Directory path:PRDBv3.0/1WPU
# Directory not found: PRDBv3.0/1WPU
#
# (1) Directory path:PRDBv3.0/2ASB
# Directory not found: PRDBv3.0/2ASB
#
# (1) Directory path:PRDBv3.0/2GIC
# Directory not found: PRDBv3.0/2GIC
#
# (1) Directory path:PRDBv3.0/2IX1
# Directory not found: PRDBv3.0/2IX1
#
# (1) Directory path:PRDBv3.0/2JEA
# Directory not found: PRDBv3.0/2JEA
#
# (1) Directory path:PRDBv3.0/2PY9
# Directory not found: PRDBv3.0/2PY9
#
# (1) Directory path:PRDBv3.0/2XNR
# Directory not found: PRDBv3.0/2XNR
#
# (1) Directory path:PRDBv3.0/3AEV
# Directory not found: PRDBv3.0/3AEV
#
# (1) Directory path:PRDBv3.0/3BX2
# Directory not found: PRDBv3.0/3BX2
#
# (1) Directory path:PRDBv3.0/3D2S
# Directory not found: PRDBv3.0/3D2S
#
# (1) Directory path:PRDBv3.0/3MDG
# Directory not found: PRDBv3.0/3MDG
#
# (1) Directory path:PRDBv3.0/3O8C
# Directory not found: PRDBv3.0/3O8C
#
# (1) Directory path:PRDBv3.0/3PF4
# Directory not found: PRDBv3.0/3PF4
#
# (1) Directory path:PRDBv3.0/3QJJ
# Directory not found: PRDBv3.0/3QJJ
#
# (1) Directory path:PRDBv3.0/3RC8
# Directory not found: PRDBv3.0/3RC8
#
# (1) Directory path:PRDBv3.0/4E78
# Directory not found: PRDBv3.0/4E78
#
# (1) Directory path:PRDBv3.0/4J7M
# Directory not found: PRDBv3.0/4J7M
#
# (1) Directory path:PRDBv3.0/4N2Q
# Directory not found: PRDBv3.0/4N2Q
#
# (1) Directory path:PRDBv3.0/5EIM
# Directory not found: PRDBv3.0/5EIM
#
# (1) Directory path:PRDBv3.0/5EX7
# Directory not found: PRDBv3.0/5EX7
#
# (1) Directory path:PRDBv3.0/5GXH
# Directory not found: PRDBv3.0/5GXH
#
# (1) Directory path:PRDBv3.0/5SZE
# Directory not found: PRDBv3.0/5SZE
#
# (1) Directory path:PRDBv3.0/5V7C
# Directory not found: PRDBv3.0/5V7C
#
# (1) Directory path:PRDBv3.0/5W0M
# Directory not found: PRDBv3.0/5W0M
#
# (1) Directory path:PRDBv3.0/5WWX
# Directory not found: PRDBv3.0/5WWX
#
# (1) Directory path:PRDBv3.0/5ZSC
# Directory not found: PRDBv3.0/5ZSC
#
# (1) Directory path:PRDBv3.0/6A4E
# Directory not found: PRDBv3.0/6A4E
#
# (1) Directory path:PRDBv3.0/6A6J
# Directory not found: PRDBv3.0/6A6J
#
# (1) Directory path:PRDBv3.0/6GC5
# Directory not found: PRDBv3.0/6GC5
#
# (1) Directory path:PRDBv3.0/6HAU
# Directory not found: PRDBv3.0/6HAU
#
# (1) Directory path:PRDBv3.0/6I0V
# Directory not found: PRDBv3.0/6I0V
#
# (1) Directory path:PRDBv3.0/6LLB
# Directory not found: PRDBv3.0/6LLB
#
# (1) Directory path:PRDBv3.0/6R9P
# Directory not found: PRDBv3.0/6R9P
#
# (1) Directory path:PRDBv3.0/6L5N
# Directory not found: PRDBv3.0/6L5N
#
# (1) Directory path:PRDBv3.0/6U6Y
# Directory not found: PRDBv3.0/6U6Y
#
# (1) Directory path:PRDBv3.0/6WXY
# Directory not found: PRDBv3.0/6WXY
#
# (1) Directory path:PRDBv3.0/6ZOT
# Directory not found: PRDBv3.0/6ZOT
#
# (1) Directory path:PRDBv3.0/7DOL
# Directory not found: PRDBv3.0/7DOL
#
# (1) Directory path:PRDBv3.0/7K5L
# Directory not found: PRDBv3.0/7K5L
#
# (1) Directory path:PRDBv3.0/7EIU
# Directory not found: PRDBv3.0/7EIU
#
# (1) Directory path:PRDBv3.0/7KL3
# Directory not found: PRDBv3.0/7KL3
#
# (1) Directory path:PRDBv3.0/7L6T
# Directory not found: PRDBv3.0/7L6T
#
# (1) Directory path:PRDBv3.0/7V4G
# Directory not found: PRDBv3.0/7V4G
#
# (1) Directory path:PRDBv3.0/7VSJ
# Directory not found: PRDBv3.0/7VSJ
#
# (1) Directory path:PRDBv3.0/7VKI
# Directory not found: PRDBv3.0/7VKI
#
# (1) Directory path:PRDBv3.0/7VKL
# Directory not found: PRDBv3.0/7VKL
#
# (1) Directory path:PRDBv3.0/7Y7Q
# Directory not found: PRDBv3.0/7Y7Q
#
# (1) Directory path:PRDBv3.0/8DZK
# Directory not found: PRDBv3.0/8DZK
#
# (1) Directory path:PRDBv3.0/8TG4
# Directory not found: PRDBv3.0/8TG4

# %%
print(f"Number of unique PDB ID in each docking case:\n{prdbv3_read_json['Docking_case'].value_counts()}\n")
# Out:
# Number of unique PDB ID in each docking case:
# Docking_case
# UB    160
# UU     27
# BU     10
# Name: count, dtype: int64

# %%
# Read PRDBv3 data directory and its contents based on the different docking cases
def get_PRDBv3_info_by_docking_case(path, df_to_parse, docking_case):
    print(f"INFO PRDBv3:\nTotal {len(df_to_parse[df_to_parse['Docking_case'] == docking_case]['C_PDB'].values)} directories in docking case {docking_case}: \n")
    # Iterate through each directory in the PRDBv3 dataset directory
    count_dir = 1
    for pdbdir in df_to_parse[df_to_parse['Docking_case'] == docking_case]['C_PDB'].values:
        try:
            print(f'({count_dir}) Directory path:{os.path.join(path, pdbdir)}')
            print(f'Total {len(os.listdir(os.path.join(path, pdbdir)))} PDB files in {pdbdir} directory.')
            print(f'All files in {pdbdir} directory:\n{os.listdir(os.path.join(path, pdbdir))}\n')
            count_dir += 1
            # Catch exception for directories not found
        except:
            print(f'Directory not found: {os.path.join(path, pdbdir)}\n')
# Read directories, files and its contents in PRDBv3 dataset directory based on docking case
get_PRDBv3_info_by_docking_case(PRDBv3_dir, prdbv3_read_json, 'UU')
# Out:
# INFO PRDBv3:
# Total 27 directories in docking case UU:
#
# (1) Directory path:PRDBv3.0/1ASY
# Directory not found: PRDBv3.0/1ASY
#
# (1) Directory path:PRDBv3.0/1B23
# Directory not found: PRDBv3.0/1B23
#
# (1) Directory path:PRDBv3.0/1C0A
# Directory not found: PRDBv3.0/1C0A
#
# (1) Directory path:PRDBv3.0/1QTQ
# Directory not found: PRDBv3.0/1QTQ
#
# (1) Directory path:PRDBv3.0/2BTE
# Directory not found: PRDBv3.0/2BTE
#
# (1) Directory path:PRDBv3.0/2DRB
# Directory not found: PRDBv3.0/2DRB
#
# (1) Directory path:PRDBv3.0/2FMT
# Directory not found: PRDBv3.0/2FMT
#
# (1) Directory path:PRDBv3.0/2ZZM
# Directory not found: PRDBv3.0/2ZZM
#
# (1) Directory path:PRDBv3.0/3HL2
# Directory not found: PRDBv3.0/3HL2
#
# (1) Directory path:PRDBv3.0/3VJR
# Directory not found: PRDBv3.0/3VJR
#
# (1) Directory path:PRDBv3.0/5X6B
# Directory not found: PRDBv3.0/5X6B
#
# (1) Directory path:PRDBv3.0/6LVR
# Directory not found: PRDBv3.0/6LVR
#
# (1) Directory path:PRDBv3.0/7YSE
# Directory not found: PRDBv3.0/7YSE
#
# (1) Directory path:PRDBv3.0/1DFU
# Directory not found: PRDBv3.0/1DFU
#
# (1) Directory path:PRDBv3.0/1FEU
# Directory not found: PRDBv3.0/1FEU
#
# (1) Directory path:PRDBv3.0/1MMS
# Directory not found: PRDBv3.0/1MMS
#
# (1) Directory path:PRDBv3.0/3IEV
# Directory not found: PRDBv3.0/3IEV
#
# (1) Directory path:PRDBv3.0/1OOA
# Directory not found: PRDBv3.0/1OOA
#
# (1) Directory path:PRDBv3.0/1R3E
# Directory not found: PRDBv3.0/1R3E
#
# (1) Directory path:PRDBv3.0/2R8S
# Directory not found: PRDBv3.0/2R8S
#
# (1) Directory path:PRDBv3.0/3SNP
# Directory not found: PRDBv3.0/3SNP
#
# (1) Directory path:PRDBv3.0/2OZB
# Directory not found: PRDBv3.0/2OZB
#
# (1) Directory path:PRDBv3.0/7P0V
# Directory not found: PRDBv3.0/7P0V
#
# (1) Directory path:PRDBv3.0/1JBS
# Directory not found: PRDBv3.0/1JBS
#
# (1) Directory path:PRDBv3.0/1WSU
# Directory not found: PRDBv3.0/1WSU
#
# (1) Directory path:PRDBv3.0/1ZBH
# Directory not found: PRDBv3.0/1ZBH
#
# (1) Directory path:PRDBv3.0/2BH2
# Directory not found: PRDBv3.0/2BH2
